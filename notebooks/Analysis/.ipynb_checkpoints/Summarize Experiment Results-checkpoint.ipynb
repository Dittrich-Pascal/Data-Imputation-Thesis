# %% [markdown]
# # Summarize Experiment Results
#
# This notebook collects the information from the single results files from the experiments

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import pandas as pd
import re
import seaborn as sns

from pathlib import Path
from experiment import read_experiment, read_csv_files
#from data_imputation_paper.plotting import plot_metric_vs_missing_fraction, plot_rank_vs_fraction_by_type, draw_cat_box_plot

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Settings

# %%
sns.set(style="whitegrid")
sns.set_context('paper', font_scale=1.5)
mpl.rcParams['lines.linewidth'] = '2'

# %%
EXPERIMENT = "corrupted_binary_experiment"
# Binary Classification
# Multiclass Classification
# Regression
# binary_experiment

EXPERIMENT_PATH = Path(f"../../results/{EXPERIMENT}/")
#EXPERIMENT_PATH = Path("../Code/results/{EXPERIMENT}/")

IMPUTE_RESULT_TYPE = "downstream_performance_mean"
#FIGURES_PATH = Path("../paper/figures/")

CLF_METRIC = "Categorical Columns"
REG_METRIC = "Numerical Columns"
print(EXPERIMENT_PATH)

#CONFIDENCE_INTERVAL = 90
# Out:
# ../../results/corrupted_binary_experiment

# %% [markdown]
# ## Import the data

# %%
# %%time

results = read_csv_files(read_experiment(EXPERIMENT_PATH), read_details=False)
results
# Out:
# CPU times: user 1.93 s, sys: 11.9 ms, total: 1.94 s
# Wall time: 1.94 s
#                        experiment           imputer   task missing_type  \
# 0     corrupted_binary_experiment        KNNImputer  40922         MNAR
# 1     corrupted_binary_experiment        KNNImputer  40922         MNAR
# 2     corrupted_binary_experiment        KNNImputer  40922         MNAR
# 3     corrupted_binary_experiment        KNNImputer  40922         MNAR
# 4     corrupted_binary_experiment        KNNImputer  40922         MNAR
# ...                           ...               ...    ...          ...
# 2167  corrupted_binary_experiment  AutoKerasImputer   1471         MCAR
# 2168  corrupted_binary_experiment  AutoKerasImputer   1471         MCAR
# 2169  corrupted_binary_experiment  AutoKerasImputer   1471         MCAR
# 2170  corrupted_binary_experiment  AutoKerasImputer   1471         MCAR
# 2171  corrupted_binary_experiment  AutoKerasImputer   1471         MCAR
#
#       missing_fraction       strategy  column                  result_type  \
# 0                 0.50  single_single  gyro_y       impute_performance_std
# 1                 0.50  single_single  gyro_y       impute_performance_std
# 2                 0.50  single_single  gyro_y       impute_performance_std
# 3                 0.30  single_single  gyro_y       impute_performance_std
# 4                 0.30  single_single  gyro_y       impute_performance_std
# ...                ...            ...     ...                          ...
# 2167              0.01  single_single      V9  downstream_performance_mean
# 2168              0.01  single_single      V9  downstream_performance_mean
# 2169              0.10  single_single      V9  downstream_performance_mean
# 2170              0.10  single_single      V9  downstream_performance_mean
# 2171              0.10  single_single      V9  downstream_performance_mean
#
#            metric      train       test  baseline  corrupted   imputed
# 0             MAE   0.259354   0.372944       NaN        NaN       NaN
# 1             MSE   5.792783  12.070804       NaN        NaN       NaN
# 2            RMSE   0.326318   0.652402       NaN        NaN       NaN
# 3             MAE   0.972128   1.404844       NaN        NaN       NaN
# 4             MSE  21.344435  25.462407       NaN        NaN       NaN
# ...           ...        ...        ...       ...        ...       ...
# 2167     F1_macro        NaN        NaN  0.551589        0.0  0.551589
# 2168  F1_weighted        NaN        NaN  0.554675        0.0  0.554675
# 2169     F1_micro        NaN        NaN  0.557744        0.0  0.557744
# 2170     F1_macro        NaN        NaN  0.551589        0.0  0.551589
# 2171  F1_weighted        NaN        NaN  0.554675        0.0  0.554675
#
# [2172 rows x 14 columns]

# %%
results.to_csv('binary_classification.csv', index=False)

# binary_classification.csv  /  binary_classification_corrupted.csv
# multiclass_classification.csv  /  multiclass_classification_corrupted.csv
# regression.csv  /  regression_corrupted.csv
