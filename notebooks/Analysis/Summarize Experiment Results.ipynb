# %% [markdown]
# # Summarize Experiment Results
#
# This notebook collects the information from the single results files from the experiments

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import pandas as pd
import re
import seaborn as sns

from pathlib import Path
from experiment import read_experiment, read_csv_files
#from data_imputation_paper.plotting import plot_metric_vs_missing_fraction, plot_rank_vs_fraction_by_type, draw_cat_box_plot

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Settings

# %%
sns.set(style="whitegrid")
sns.set_context('paper', font_scale=1.5)
mpl.rcParams['lines.linewidth'] = '2'

# %%
EXPERIMENT = "corrupted_regression_experiment"
#corrupted_binary_experiment
#corrupted_multi_experiment
#corrupted_regression_experiment

EXPERIMENT_PATH = Path(f"../../results/{EXPERIMENT}/")
#EXPERIMENT_PATH = Path("../Code/results/{EXPERIMENT}/")

IMPUTE_RESULT_TYPE = "downstream_performance_mean"
#FIGURES_PATH = Path("../paper/figures/")

CLF_METRIC = "Categorical Columns"
REG_METRIC = "Numerical Columns"
print(EXPERIMENT_PATH)

#CONFIDENCE_INTERVAL = 90
# Out:
# ../../results/corrupted_regression_experiment

# %% [markdown]
# ## Import the data

# %%
# %%time

results = read_csv_files(read_experiment(EXPERIMENT_PATH), read_details=False)
results
# Out:
# CPU times: user 4.76 s, sys: 59.8 ms, total: 4.82 s
# Wall time: 4.82 s
#                            experiment           imputer   task missing_type  \
# 0     corrupted_regression_experiment        KNNImputer    287         MNAR
# 1     corrupted_regression_experiment        KNNImputer    287         MNAR
# 2     corrupted_regression_experiment        KNNImputer    287         MNAR
# 3     corrupted_regression_experiment        KNNImputer    287         MNAR
# 4     corrupted_regression_experiment        KNNImputer    287         MNAR
# ...                               ...               ...    ...          ...
# 8443  corrupted_regression_experiment  AutoKerasImputer  42712         MCAR
# 8444  corrupted_regression_experiment  AutoKerasImputer  42712         MCAR
# 8445  corrupted_regression_experiment  AutoKerasImputer  42712         MCAR
# 8446  corrupted_regression_experiment  AutoKerasImputer  42712         MCAR
# 8447  corrupted_regression_experiment  AutoKerasImputer  42712         MCAR
#
#       missing_fraction       strategy     column                  result_type  \
# 0                 0.50  single_single  sulphates       impute_performance_std
# 1                 0.50  single_single  sulphates       impute_performance_std
# 2                 0.50  single_single  sulphates       impute_performance_std
# 3                 0.30  single_single  sulphates       impute_performance_std
# 4                 0.30  single_single  sulphates       impute_performance_std
# ...                ...            ...        ...                          ...
# 8443              0.01  single_single   humidity  downstream_performance_mean
# 8444              0.01  single_single   humidity  downstream_performance_mean
# 8445              0.10  single_single   humidity  downstream_performance_mean
# 8446              0.10  single_single   humidity  downstream_performance_mean
# 8447              0.10  single_single   humidity  downstream_performance_mean
#
#      metric     train      test      baseline  corrupted       imputed
# 0       MAE  0.005105  0.008916           NaN        NaN           NaN
# 1       MSE  0.001035  0.001012           NaN        NaN           NaN
# 2      RMSE  0.004077  0.004217           NaN        NaN           NaN
# 3       MAE  0.024398  0.012255           NaN        NaN           NaN
# 4       MSE  0.005600  0.001942           NaN        NaN           NaN
# ...     ...       ...       ...           ...        ...           ...
# 8443    MSE       NaN       NaN  22363.007764        0.0  22353.299095
# 8444   RMSE       NaN       NaN    149.542662        0.0    149.510195
# 8445    MAE       NaN       NaN    100.992727        0.0    100.980472
# 8446    MSE       NaN       NaN  22418.408627        0.0  22401.921135
# 8447   RMSE       NaN       NaN    149.727782        0.0    149.672686
#
# [8448 rows x 14 columns]

# %%
results.to_csv('regression_corrupted.csv', index=False)

# binary_classification.csv  /  binary_classification_corrupted.csv
# multiclass_classification.csv  /  multiclass_classification_corrupted.csv
# regression.csv  /  regression_corrupted.csv
