# %% [markdown]
# # Visualize Results: Downstream Performance - Multiclass Classification Corrupted Experiments
#
# Notebook wurde angepasst -> für Tests nutzen!
#
# This notebook should answer the questions: *Does imputation lead to better downstream performances?*
#
# Data needs to be preprocessed with other notebook, her we only import two csv files with raw data regarding the results of the experiment and information about the used datasets!
#
# ## Notebook Structure
#
# * Application Scenario 2 - Downstream Performance
#    * Categorical  Columns (Classification)
#    * Numerical Columns (Regression)
#    * Heterogenous Columns (Classification and Regression Combined)

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import pandas as pd
import re
import seaborn as sns

from pathlib import Path

import plotly as py
import plotly.express as px
import plotly.graph_objects as go
import xarray as xr


# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Settings

# %%
sns.set(style="whitegrid")
sns.set_context('paper', font_scale=1.5)
mpl.rcParams['lines.linewidth'] = '2'

# %%
CLF_METRIC = "F1_macro"
REG_METRIC = "RMSE"

#CLF_METRIC = "Classification Tasks"
#REG_METRIC = "Regression Tasks"

DOWNSTREAM_RESULT_TYPE = "downstream_performance_mean"
IMPUTE_RESULT_TYPE = "impute_performance_mean"

FIGURES_PATH = Path(f"../paper/figures/")

# %% [markdown]
# ## Data Preparation

# %%
#read results.csv file here!

# Pick whether you want to analyze the "Regression" Experiment oder the "Regression Corrupted" Experiment

#results = pd.read_csv('regression_corrupted.csv')
results = pd.read_csv('../multiclass_classification_corrupted.csv')
# Preresults.head()
results
# Out:
#                       experiment           imputer   task missing_type  \
# 0     corrupted_multi_experiment        KNNImputer     30         MNAR
# 1     corrupted_multi_experiment        KNNImputer     30         MNAR
# 2     corrupted_multi_experiment        KNNImputer     30         MNAR
# 3     corrupted_multi_experiment        KNNImputer     30         MNAR
# 4     corrupted_multi_experiment        KNNImputer     30         MNAR
# ...                          ...               ...    ...          ...
# 8539  corrupted_multi_experiment  AutoKerasImputer  40685         MCAR
# 8540  corrupted_multi_experiment  AutoKerasImputer  40685         MCAR
# 8541  corrupted_multi_experiment  AutoKerasImputer  40685         MCAR
# 8542  corrupted_multi_experiment  AutoKerasImputer  40685         MCAR
# 8543  corrupted_multi_experiment  AutoKerasImputer  40685         MCAR
#
#       missing_fraction       strategy column                  result_type  \
# 0                 0.50  single_single  eccen       impute_performance_std
# 1                 0.50  single_single  eccen       impute_performance_std
# 2                 0.50  single_single  eccen       impute_performance_std
# 3                 0.30  single_single  eccen       impute_performance_std
# 4                 0.30  single_single  eccen       impute_performance_std
# ...                ...            ...    ...                          ...
# 8539              0.01  single_single     A2  downstream_performance_mean
# 8540              0.01  single_single     A2  downstream_performance_mean
# 8541              0.10  single_single     A2  downstream_performance_mean
# 8542              0.10  single_single     A2  downstream_performance_mean
# 8543              0.10  single_single     A2  downstream_performance_mean
#
#            metric      train       test  baseline  corrupted   imputed
# 0             MAE   1.824974   0.684856       NaN        NaN       NaN
# 1             MSE  70.315798  67.553193       NaN        NaN       NaN
# 2            RMSE   3.869505   4.132480       NaN        NaN       NaN
# 3             MAE   0.802552   0.406847       NaN        NaN       NaN
# 4             MSE  15.222242   1.146581       NaN        NaN       NaN
# ...           ...        ...        ...       ...        ...       ...
# 8539     F1_macro        NaN        NaN  0.382647        0.0  0.382647
# 8540  F1_weighted        NaN        NaN  0.920582        0.0  0.920582
# 8541     F1_micro        NaN        NaN  0.927931        0.0  0.927931
# 8542     F1_macro        NaN        NaN  0.382871        0.0  0.382871
# 8543  F1_weighted        NaN        NaN  0.920755        0.0  0.920755
#
# [8544 rows x 14 columns]

# %%
# Filtering the relevant data for downstream analysis

na_impute_results = results[
    (results["result_type"] == IMPUTE_RESULT_TYPE) & 
    (results["metric"].isin(["F1_macro", "RMSE"]))
]
na_impute_results.drop(["baseline", "corrupted", "imputed"], axis=1, inplace=True)
na_impute_results = na_impute_results[na_impute_results.isna().any(axis=1)]
na_impute_results.shape
# Out:
# /tmp/ipykernel_2178373/3401284833.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (0, 11)

# %%
# check if strategy type is correct!
STRATEGY_TYPE = "single_single"

downstream_results = results[
    (results["result_type"] == DOWNSTREAM_RESULT_TYPE) & 
    (results["metric"].isin(["F1_macro", "RMSE"]) &
    (results["strategy"] == STRATEGY_TYPE))
]

# remove experiments where imputation failed
downstream_results = downstream_results.merge(
    na_impute_results,
    how = "left",
    validate = "one_to_one",
    indicator = True,
    suffixes=("", "_imp"),
    on = ["experiment", "imputer", "task", "missing_type", "missing_fraction", "strategy", "column"]
)
downstream_results = downstream_results[downstream_results["_merge"]=="left_only"]

assert len(results["strategy"].unique()) == 1
downstream_results.drop(["experiment", "strategy", "result_type_imp", "metric_imp", "train", "test", "train_imp", "test_imp", "_merge"], axis=1, inplace=True)

downstream_results = downstream_results.rename(
    {
        "imputer": "Imputation_Method",
        "task": "Task",
        "missing_type": "Missing Type",
        "missing_fraction": "Missing Fraction",
        "column": "Column",
        "baseline": "Baseline",
        "imputed": "Imputed",
        "corrupted": "Corrupted"
    },
    axis = 1
)

# %%
rename_imputer_dict = {
    "ModeImputer": "Mean/Mode",
    "KNNImputer": "KNN",
    "ForestImputer": "Random Forest",
    "AutoKerasImputer": "Discriminative DL",
    "VAEImputer": "VAE",
    "GAINImputer": "GAIN"    
}

rename_metric_dict = {
    "F1_macro": CLF_METRIC,
    "RMSE": REG_METRIC
}

downstream_results = downstream_results.replace(rename_imputer_dict)
downstream_results = downstream_results.replace(rename_metric_dict)

downstream_results
# Out:
#      Imputation_Method   Task Missing Type  Missing Fraction Column  \
# 0                  KNN     30         MNAR              0.50  eccen
# 1                  KNN     30         MNAR              0.30  eccen
# 2                  KNN     30         MNAR              0.01  eccen
# 3                  KNN     30         MNAR              0.10  eccen
# 4                  KNN     30          MAR              0.50  eccen
# ..                 ...    ...          ...               ...    ...
# 707  Discriminative DL  40685          MAR              0.10     A2
# 708  Discriminative DL  40685         MCAR              0.50     A2
# 709  Discriminative DL  40685         MCAR              0.30     A2
# 710  Discriminative DL  40685         MCAR              0.01     A2
# 711  Discriminative DL  40685         MCAR              0.10     A2
#
#                      result_type    metric  Baseline  Corrupted   Imputed
# 0    downstream_performance_mean  F1_macro  0.728825        0.0  0.728026
# 1    downstream_performance_mean  F1_macro  0.673140        0.0  0.673140
# 2    downstream_performance_mean  F1_macro  0.673140        0.0  0.673140
# 3    downstream_performance_mean  F1_macro  0.749369        0.0  0.749369
# 4    downstream_performance_mean  F1_macro  0.714564        0.0  0.715378
# ..                           ...       ...       ...        ...       ...
# 707  downstream_performance_mean  F1_macro  0.383420        0.0  0.383415
# 708  downstream_performance_mean  F1_macro  0.382006        0.0  0.381955
# 709  downstream_performance_mean  F1_macro  0.384540        0.0  0.384440
# 710  downstream_performance_mean  F1_macro  0.382647        0.0  0.382647
# 711  downstream_performance_mean  F1_macro  0.382871        0.0  0.382871
#
# [712 rows x 10 columns]

# %% [markdown]
# ### Robustness: check which imputers yielded `NaN`values

# %%
for col in downstream_results.columns:
    na_sum = downstream_results[col].isna().sum()
    if na_sum > 0:
        print("-----" * 10)        
        print(col, na_sum)
        print("-----" * 10)        
        na_idx = downstream_results[col].isna()
        print(downstream_results.loc[na_idx, "Imputation Method"].value_counts(dropna=False))
        print("\n")

# %% [markdown]
# ## Adding Dataset Info, Sorting and Ranking

# %%
# Sortierung der Daten

#downstream_results_full_sort = pd.read_csv('downstream_results.csv')
downstream_results_full_sort = downstream_results


#impute_results_full_sort = impute_results_full_sort.sort_values(['Task'], ascending=[True])
downstream_results_full_sort = downstream_results_full_sort.sort_values(['Task', 'Missing Type', 'Missing Fraction', 'Imputed'], ascending=[True, True, True, True])
#print(downstream_results_full_sort)
downstream_results_full_sort.head()


#downstream_results_full_sort.to_csv('downstream_results_full_sort.csv')
# Out:
#      Imputation_Method  Task Missing Type  Missing Fraction Column  \
# 600  Discriminative DL    30          MAR              0.01  eccen
# 360      Random Forest    30          MAR              0.01  eccen
# 126               GAIN    30          MAR              0.01  eccen
# 6                  KNN    30          MAR              0.01  eccen
# 240          Mean/Mode    30          MAR              0.01  eccen
#
#                      result_type    metric  Baseline  Corrupted   Imputed
# 600  downstream_performance_mean  F1_macro  0.673140        0.0  0.673140
# 360  downstream_performance_mean  F1_macro  0.674928        0.0  0.674928
# 126  downstream_performance_mean  F1_macro  0.681451        0.0  0.681451
# 6    downstream_performance_mean  F1_macro  0.702542        0.0  0.702542
# 240  downstream_performance_mean  F1_macro  0.738395        0.0  0.738240

# %%
# add dataset information from other csv file

dataset_info = pd.read_csv('../datasets_information_overview.csv')
dataset_info = dataset_info.rename(columns={"did": "Task"})


downstream_results_full_sort = pd.merge(downstream_results_full_sort, dataset_info, on='Task')
#downstream_results_full_sort.to_csv('downstream_results_full_sort_testtesttest.csv')
downstream_results_full_sort.head()
# Out:
#    Imputation_Method  Task Missing Type  Missing Fraction Column  \
# 0  Discriminative DL    30          MAR              0.01  eccen
# 1      Random Forest    30          MAR              0.01  eccen
# 2               GAIN    30          MAR              0.01  eccen
# 3                KNN    30          MAR              0.01  eccen
# 4          Mean/Mode    30          MAR              0.01  eccen
#
#                    result_type    metric  Baseline  Corrupted   Imputed  \
# 0  downstream_performance_mean  F1_macro  0.673140        0.0  0.673140
# 1  downstream_performance_mean  F1_macro  0.674928        0.0  0.674928
# 2  downstream_performance_mean  F1_macro  0.681451        0.0  0.681451
# 3  downstream_performance_mean  F1_macro  0.702542        0.0  0.702542
# 4  downstream_performance_mean  F1_macro  0.738395        0.0  0.738240
#
#    Unnamed: 0         name  MajorityClassSize  MinorityClassSize  \
# 0          48  page-blocks             4913.0               28.0
# 1          48  page-blocks             4913.0               28.0
# 2          48  page-blocks             4913.0               28.0
# 3          48  page-blocks             4913.0               28.0
# 4          48  page-blocks             4913.0               28.0
#
#    NumberOfFeatures  NumberOfInstances  NumberOfNumericFeatures  \
# 0              11.0             5473.0                     10.0
# 1              11.0             5473.0                     10.0
# 2              11.0             5473.0                     10.0
# 3              11.0             5473.0                     10.0
# 4              11.0             5473.0                     10.0
#
#    NumberOfCategoricalFeatures  NumberOfClasses
# 0                          1.0              5.0
# 1                          1.0              5.0
# 2                          1.0              5.0
# 3                          1.0              5.0
# 4                          1.0              5.0

# %%
# Ranking of downstream performance per data constellation

EXPERIMENTAL_CONDITIONS = ["Task", "Missing Type", "Missing Fraction", "Column", "result_type"]

downstream_results_rank = downstream_results_full_sort

#clf_row_idx = impute_results["metric"] == CLF_METRIC
#reg_row_idx = impute_results["metric"] == REG_METRIC

downstream_results_rank["Downstream Performance Rank"] = downstream_results_rank.groupby(EXPERIMENTAL_CONDITIONS).rank(ascending=False, na_option="bottom", method="min")["Imputed"]
downstream_results_rank.to_csv('downstream_results_complete_overview.csv')
downstream_results_rank.head()
# Out:
#    Imputation_Method  Task Missing Type  Missing Fraction Column  \
# 0  Discriminative DL    30          MAR              0.01  eccen
# 1      Random Forest    30          MAR              0.01  eccen
# 2               GAIN    30          MAR              0.01  eccen
# 3                KNN    30          MAR              0.01  eccen
# 4          Mean/Mode    30          MAR              0.01  eccen
#
#                    result_type    metric  Baseline  Corrupted   Imputed  \
# 0  downstream_performance_mean  F1_macro  0.673140        0.0  0.673140
# 1  downstream_performance_mean  F1_macro  0.674928        0.0  0.674928
# 2  downstream_performance_mean  F1_macro  0.681451        0.0  0.681451
# 3  downstream_performance_mean  F1_macro  0.702542        0.0  0.702542
# 4  downstream_performance_mean  F1_macro  0.738395        0.0  0.738240
#
#    Unnamed: 0         name  MajorityClassSize  MinorityClassSize  \
# 0          48  page-blocks             4913.0               28.0
# 1          48  page-blocks             4913.0               28.0
# 2          48  page-blocks             4913.0               28.0
# 3          48  page-blocks             4913.0               28.0
# 4          48  page-blocks             4913.0               28.0
#
#    NumberOfFeatures  NumberOfInstances  NumberOfNumericFeatures  \
# 0              11.0             5473.0                     10.0
# 1              11.0             5473.0                     10.0
# 2              11.0             5473.0                     10.0
# 3              11.0             5473.0                     10.0
# 4              11.0             5473.0                     10.0
#
#    NumberOfCategoricalFeatures  NumberOfClasses  Downstream Performance Rank
# 0                          1.0              5.0                          6.0
# 1                          1.0              5.0                          5.0
# 2                          1.0              5.0                          4.0
# 3                          1.0              5.0                          3.0
# 4                          1.0              5.0                          2.0

# %%
# Merge the two columns "Missing Type" and "Missing Fraction"

downstream_results_rank['Missing Type'] = downstream_results_rank['Missing Type'].astype(str)
downstream_results_rank['Missing Fraction'] = downstream_results_rank['Missing Fraction'].astype(str)
datatype_new = downstream_results_rank.dtypes
#print(datatype_new)

downstream_results_rank['Data_Constellation'] = downstream_results_rank['Missing Type'] + ' - ' + downstream_results_rank['Missing Fraction']
downstream_results_rank.to_csv('downstream_results_rank_temp.csv')
downstream_results_rank_heatmap2 = downstream_results_rank.copy()
downstream_results_rank.head()
# Out:
#    Imputation_Method  Task Missing Type Missing Fraction Column  \
# 0  Discriminative DL    30          MAR             0.01  eccen
# 1      Random Forest    30          MAR             0.01  eccen
# 2               GAIN    30          MAR             0.01  eccen
# 3                KNN    30          MAR             0.01  eccen
# 4          Mean/Mode    30          MAR             0.01  eccen
#
#                    result_type    metric  Baseline  Corrupted   Imputed  ...  \
# 0  downstream_performance_mean  F1_macro  0.673140        0.0  0.673140  ...
# 1  downstream_performance_mean  F1_macro  0.674928        0.0  0.674928  ...
# 2  downstream_performance_mean  F1_macro  0.681451        0.0  0.681451  ...
# 3  downstream_performance_mean  F1_macro  0.702542        0.0  0.702542  ...
# 4  downstream_performance_mean  F1_macro  0.738395        0.0  0.738240  ...
#
#           name MajorityClassSize  MinorityClassSize  NumberOfFeatures  \
# 0  page-blocks            4913.0               28.0              11.0
# 1  page-blocks            4913.0               28.0              11.0
# 2  page-blocks            4913.0               28.0              11.0
# 3  page-blocks            4913.0               28.0              11.0
# 4  page-blocks            4913.0               28.0              11.0
#
#    NumberOfInstances  NumberOfNumericFeatures  NumberOfCategoricalFeatures  \
# 0             5473.0                     10.0                          1.0
# 1             5473.0                     10.0                          1.0
# 2             5473.0                     10.0                          1.0
# 3             5473.0                     10.0                          1.0
# 4             5473.0                     10.0                          1.0
#
#    NumberOfClasses  Downstream Performance Rank  Data_Constellation
# 0              5.0                          6.0          MAR - 0.01
# 1              5.0                          5.0          MAR - 0.01
# 2              5.0                          4.0          MAR - 0.01
# 3              5.0                          3.0          MAR - 0.01
# 4              5.0                          2.0          MAR - 0.01
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Analyzing Performance based on Rank and Improvement per Data Constellation

# %% [markdown]
# Hier die Rechnung -> Bestes Ergebnis pro "Experimental condition" - Beste Methode im Durchschnitt
#
# ToDo´s für restliche Auswertung (Mathematische Part)
# - Beste Imp-Methode je Datensatz ermitteln (-> via Ranking am besten, je Konstellation (Bsp. MAR 0.01)
# - durchschnittliche Platzierung jeder Imp-Methode ermitteln (Ranking -> dann je Konstellation (Bsp. MAR 0.01)
# - Beste Imp je Datensatz mit durchschnittlich bester Imp vergleichen (Liste mit beste Imp & Liste mit Durchschn. Imp -> VGL)
# (jede Konstellation genau einmal in jeder Liste)

# %%
data = downstream_results_rank.copy()

# Count amount of different Data constellations in column "Data_Constellation"
dc_unique = data.Data_Constellation.unique().size
print(dc_unique, "Data Constellations")
print("_____________________")
# Count amount of 1.0 Ranking result in column "Downstream Performance Rank" 
rank_count = data['Downstream Performance Rank'].value_counts()
print(rank_count)
print("_____________________")
# Filter for 1.0 Ranking -> Overview -> save as csv
rank_1 = data.loc[data['Downstream Performance Rank'] == 1.0]
rank_1.to_csv('rank_1.csv')

print("_____________________")
# Count how often each Imputation Method is present -> most "wins"
rank_wins = rank_1['Imputation_Method'].value_counts()
print(rank_wins)
print("_____________________")
# Take initial overview and filter for each imputation method and calculate average rank and average improvement
methods = ['Random Forest', 'KNN', 'Mean/Mode', 'VAE', 'GAIN', 'Discriminative DL']
for i in methods:
    df_average_rank = data.loc[data['Imputation_Method'] == i]
    len_ar = len(df_average_rank)
    print(len_ar, "Amount of results available")
    rank_pos = df_average_rank['Downstream Performance Rank'].value_counts().sort_index(ascending=True)
    print(rank_pos)
    average_rank = df_average_rank["Downstream Performance Rank"].mean()
    print("Average Rank for", i, "is", average_rank)
    #average_improvement = df_average_rank["Improvement"].mean()
    #print("Average Improvement to baseline is", average_improvement)
    print("_____________________")
# Out:
# 12 Data Constellations
# _____________________
# 1.0    124
# 4.0    121
# 3.0    121
# 5.0    117
# 2.0    117
# 6.0    112
# Name: Downstream Performance Rank, dtype: int64
# _____________________
# _____________________
# GAIN                 24
# KNN                  24
# VAE                  23
# Random Forest        20
# Mean/Mode            20
# Discriminative DL    13
# Name: Imputation_Method, dtype: int64
# _____________________
# 120 Amount of results available
# 1.0    20
# 2.0    22
# 3.0    24
# 4.0    23
# 5.0    16
# 6.0    15
# Name: Downstream Performance Rank, dtype: int64
# Average Rank for Random Forest is 3.316666666666667
# _____________________
# 120 Amount of results available
# 1.0    24
# 2.0    18
# 3.0    25
# 4.0    15
# 5.0    25
# 6.0    13
# Name: Downstream Performance Rank, dtype: int64
# Average Rank for KNN is 3.316666666666667
# _____________________
# 120 Amount of results available
# 1.0    20
# 2.0    24
# 3.0    22
# 4.0    15
# 5.0    19
# 6.0    20
# Name: Downstream Performance Rank, dtype: int64
# Average Rank for Mean/Mode is 3.408333333333333
# _____________________
# 120 Amount of results available
# 1.0    23
# 2.0    20
# 3.0    18
# 4.0    14
# 5.0    23
# 6.0    22
# Name: Downstream Performance Rank, dtype: int64
# Average Rank for VAE is 3.5
# _____________________
# 114 Amount of results available
# 1.0    24
# 2.0    14
# 3.0    14
# 4.0    25
# 5.0    15
# 6.0    22
# Name: Downstream Performance Rank, dtype: int64
# Average Rank for GAIN is 3.517543859649123
# _____________________
# 118 Amount of results available
# 1.0    13
# 2.0    19
# 3.0    18
# 4.0    29
# 5.0    19
# 6.0    20
# Name: Downstream Performance Rank, dtype: int64
# Average Rank for Discriminative DL is 3.694915254237288
# _____________________

# %%
rank_1.head()
# Out:
#    Imputation_Method  Task Missing Type Missing Fraction Column  \
# 5                VAE    30          MAR             0.01  eccen
# 11              GAIN    30          MAR              0.1  eccen
# 17               VAE    30          MAR              0.3  eccen
# 23     Random Forest    30          MAR              0.5  eccen
# 29         Mean/Mode    30         MCAR             0.01  eccen
#
#                     result_type    metric  Baseline  Corrupted   Imputed  ...  \
# 5   downstream_performance_mean  F1_macro  0.738395        0.0  0.738395  ...
# 11  downstream_performance_mean  F1_macro  0.743449        0.0  0.744342  ...
# 17  downstream_performance_mean  F1_macro  0.751008        0.0  0.751215  ...
# 23  downstream_performance_mean  F1_macro  0.752634        0.0  0.753104  ...
# 29  downstream_performance_mean  F1_macro  0.751390        0.0  0.750793  ...
#
#            name MajorityClassSize  MinorityClassSize  NumberOfFeatures  \
# 5   page-blocks            4913.0               28.0              11.0
# 11  page-blocks            4913.0               28.0              11.0
# 17  page-blocks            4913.0               28.0              11.0
# 23  page-blocks            4913.0               28.0              11.0
# 29  page-blocks            4913.0               28.0              11.0
#
#     NumberOfInstances  NumberOfNumericFeatures  NumberOfCategoricalFeatures  \
# 5              5473.0                     10.0                          1.0
# 11             5473.0                     10.0                          1.0
# 17             5473.0                     10.0                          1.0
# 23             5473.0                     10.0                          1.0
# 29             5473.0                     10.0                          1.0
#
#     NumberOfClasses  Downstream Performance Rank  Data_Constellation
# 5               5.0                          1.0          MAR - 0.01
# 11              5.0                          1.0           MAR - 0.1
# 17              5.0                          1.0           MAR - 0.3
# 23              5.0                          1.0           MAR - 0.5
# 29              5.0                          1.0         MCAR - 0.01
#
# [5 rows x 21 columns]

# %%
# Calculate average impovement to baseline over all datasets per method

# %%
# Take initial overview and filter best average imputation method and take filtered dataframe from 1.0 Ranking
# Where Data_Constellation identical -> Ranking 1.0 [Improvement] - Best_Imp_Method [Improvement]
# Write Difference in seperat column - > Calculate Average improvement

AVERAGE_BEST_IMPUTATION_METHOD = "KNN"

# Adjust the following depending on the previous results
av_best = data.loc[data['Imputation_Method'] == AVERAGE_BEST_IMPUTATION_METHOD]
av_best['Task'] = av_best['Task'].astype(str)
av_best['Data_Constellation'] = av_best['Data_Constellation'] + ' - ' + av_best['Task']

av_best = av_best[['Imputation_Method', 'Imputed', 'Data_Constellation', 'Downstream Performance Rank']]
av_best = av_best.rename(columns={'Imputation_Method':'Imputation_Method_average', 
                               'Imputed':'Imputed_average',
                                 'Downstream Performance Rank':'Downstream Performance Rank Average'})

#av_best.head()

rank_1['Task'] = rank_1['Task'].astype(str)
rank_1['Data_Constellation'] = rank_1['Data_Constellation'] + ' - ' + rank_1['Task']
rank_1 = rank_1[['Imputation_Method', 'Imputed', 'Data_Constellation', 'Downstream Performance Rank']]
rank_1 = rank_1.rename(columns={'Imputation_Method':'Imputation_Method_best', 
                               'Imputed':'Imputed_best',
                               'Downstream Performance Rank':'Downstream Performance Rank Best'})

performance_difference = pd.merge(av_best, rank_1, on='Data_Constellation')
performance_difference.head()
# Out:
# /tmp/ipykernel_2178373/994977960.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/994977960.py:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/994977960.py:19: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/994977960.py:20: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Imputation_Method_average  Imputed_average Data_Constellation  \
# 0                       KNN         0.702542    MAR - 0.01 - 30
# 1                       KNN         0.674449     MAR - 0.1 - 30
# 2                       KNN         0.643422     MAR - 0.3 - 30
# 3                       KNN         0.715378     MAR - 0.5 - 30
# 4                       KNN         0.711018   MCAR - 0.01 - 30
#
#    Downstream Performance Rank Average Imputation_Method_best  Imputed_best  \
# 0                                  3.0                    VAE      0.738395
# 1                                  5.0                   GAIN      0.744342
# 2                                  6.0                    VAE      0.751215
# 3                                  5.0          Random Forest      0.753104
# 4                                  5.0              Mean/Mode      0.750793
#
#    Downstream Performance Rank Best
# 0                               1.0
# 1                               1.0
# 2                               1.0
# 3                               1.0
# 4                               1.0

# %%
#performance_difference['Imputed_best'] = performance_difference['Imputed_best'] 
#performance_difference['Imputed_average'] = performance_difference['Imputed_average'] 

performance_difference['Performance Difference Best to Average'] = performance_difference['Imputed_best'] - performance_difference['Imputed_average']
Average_Difference = performance_difference['Performance Difference Best to Average'].mean()

print("Average Difference for F1 Score", Average_Difference)
# Out:
# Average Difference for F1 Score 0.015016058228635979

# %%
# Prozentuale Verbesserung

performance_difference['Performance Difference Best to Average in Percentage'] = ((performance_difference['Imputed_best'] - performance_difference['Imputed_average'])/performance_difference['Imputed_best'])*100
Average_Difference_per = performance_difference['Performance Difference Best to Average in Percentage'].mean()

print("Based on F1 Score the Average best method is worse than the best method by this percentage", Average_Difference_per)
# Out:
# Based on F1 Score the Average best method is worse than the best method by this percentage 4.8755820408790065

# %%
performance_difference.to_csv('performance_difference.csv')

# %%
performance_difference
# Out:
#     Imputation_Method_average  Imputed_average   Data_Constellation  \
# 0                         KNN         0.702542      MAR - 0.01 - 30
# 1                         KNN         0.674449       MAR - 0.1 - 30
# 2                         KNN         0.643422       MAR - 0.3 - 30
# 3                         KNN         0.715378       MAR - 0.5 - 30
# 4                         KNN         0.711018     MCAR - 0.01 - 30
# ..                        ...              ...                  ...
# 119                       KNN         0.240619  MNAR - 0.01 - 41671
# 120                       KNN         0.240619  MNAR - 0.01 - 41671
# 121                       KNN         0.239984   MNAR - 0.1 - 41671
# 122                       KNN         0.239941   MNAR - 0.3 - 41671
# 123                       KNN         0.265395   MNAR - 0.5 - 41671
#
#      Downstream Performance Rank Average Imputation_Method_best  Imputed_best  \
# 0                                    3.0                    VAE      0.738395
# 1                                    5.0                   GAIN      0.744342
# 2                                    6.0                    VAE      0.751215
# 3                                    5.0          Random Forest      0.753104
# 4                                    5.0              Mean/Mode      0.750793
# ..                                   ...                    ...           ...
# 119                                  1.0          Random Forest      0.240619
# 120                                  1.0      Discriminative DL      0.240619
# 121                                  3.0      Discriminative DL      0.241994
# 122                                  5.0              Mean/Mode      0.244943
# 123                                  1.0                    KNN      0.265395
#
#      Downstream Performance Rank Best  Performance Difference Best to Average  \
# 0                                 1.0                                0.035853
# 1                                 1.0                                0.069892
# 2                                 1.0                                0.107794
# 3                                 1.0                                0.037726
# 4                                 1.0                                0.039774
# ..                                ...                                     ...
# 119                               1.0                                0.000000
# 120                               1.0                                0.000000
# 121                               1.0                                0.002009
# 122                               1.0                                0.005003
# 123                               1.0                                0.000000
#
#      Performance Difference Best to Average in Percentage
# 0                                             4.855474
# 1                                             9.389816
# 2                                            14.349251
# 3                                             5.009445
# 4                                             5.297653
# ..                                                 ...
# 119                                           0.000000
# 120                                           0.000000
# 121                                           0.830283
# 122                                           2.042390
# 123                                           0.000000
#
# [124 rows x 9 columns]

# %% [markdown]
# ## Analysis and Ranking based on F1 Score

# %%
#downstream_results_rank.drop(['Unnamed: 0.1'], axis=1)
downstream_results_rank
# Out:
#      Imputation_Method   Task Missing Type Missing Fraction Column  \
# 0    Discriminative DL     30          MAR             0.01  eccen
# 1        Random Forest     30          MAR             0.01  eccen
# 2                 GAIN     30          MAR             0.01  eccen
# 3                  KNN     30          MAR             0.01  eccen
# 4            Mean/Mode     30          MAR             0.01  eccen
# ..                 ...    ...          ...              ...    ...
# 707  Discriminative DL  41671         MNAR              0.5     a9
# 708          Mean/Mode  41671         MNAR              0.5     a9
# 709                VAE  41671         MNAR              0.5     a9
# 710               GAIN  41671         MNAR              0.5     a9
# 711                KNN  41671         MNAR              0.5     a9
#
#                      result_type    metric  Baseline  Corrupted   Imputed  \
# 0    downstream_performance_mean  F1_macro  0.673140        0.0  0.673140
# 1    downstream_performance_mean  F1_macro  0.674928        0.0  0.674928
# 2    downstream_performance_mean  F1_macro  0.681451        0.0  0.681451
# 3    downstream_performance_mean  F1_macro  0.702542        0.0  0.702542
# 4    downstream_performance_mean  F1_macro  0.738395        0.0  0.738240
# ..                           ...       ...       ...        ...       ...
# 707  downstream_performance_mean  F1_macro  0.240118        0.0  0.240732
# 708  downstream_performance_mean  F1_macro  0.239275        0.0  0.240780
# 709  downstream_performance_mean  F1_macro  0.241995        0.0  0.242421
# 710  downstream_performance_mean  F1_macro  0.239877        0.0  0.243434
# 711  downstream_performance_mean  F1_macro  0.264992        0.0  0.265395
#
#      ...               name MajorityClassSize  MinorityClassSize  \
# 0    ...        page-blocks            4913.0               28.0
# 1    ...        page-blocks            4913.0               28.0
# 2    ...        page-blocks            4913.0               28.0
# 3    ...        page-blocks            4913.0               28.0
# 4    ...        page-blocks            4913.0               28.0
# ..   ...                ...               ...                ...
# 707  ...  microaggregation2           11162.0              743.0
# 708  ...  microaggregation2           11162.0              743.0
# 709  ...  microaggregation2           11162.0              743.0
# 710  ...  microaggregation2           11162.0              743.0
# 711  ...  microaggregation2           11162.0              743.0
#
#      NumberOfFeatures  NumberOfInstances  NumberOfNumericFeatures  \
# 0                11.0             5473.0                     10.0
# 1                11.0             5473.0                     10.0
# 2                11.0             5473.0                     10.0
# 3                11.0             5473.0                     10.0
# 4                11.0             5473.0                     10.0
# ..                ...                ...                      ...
# 707              21.0            20000.0                     20.0
# 708              21.0            20000.0                     20.0
# 709              21.0            20000.0                     20.0
# 710              21.0            20000.0                     20.0
# 711              21.0            20000.0                     20.0
#
#      NumberOfCategoricalFeatures  NumberOfClasses  \
# 0                            1.0              5.0
# 1                            1.0              5.0
# 2                            1.0              5.0
# 3                            1.0              5.0
# 4                            1.0              5.0
# ..                           ...              ...
# 707                          1.0              5.0
# 708                          1.0              5.0
# 709                          1.0              5.0
# 710                          1.0              5.0
# 711                          1.0              5.0
#
#      Downstream Performance Rank  Data_Constellation
# 0                            6.0          MAR - 0.01
# 1                            5.0          MAR - 0.01
# 2                            4.0          MAR - 0.01
# 3                            3.0          MAR - 0.01
# 4                            2.0          MAR - 0.01
# ..                           ...                 ...
# 707                          5.0          MNAR - 0.5
# 708                          4.0          MNAR - 0.5
# 709                          3.0          MNAR - 0.5
# 710                          2.0          MNAR - 0.5
# 711                          1.0          MNAR - 0.5
#
# [712 rows x 21 columns]

# %%
# Relative Difference in Percent -> Best Method to Average Best Method

#AVERAGE_BEST_IMPUTATION_METHOD = "KNN"

data = downstream_results_rank.copy()
data['Task'] = data['Task'].astype(str)
data['Data_Constellation_full'] = data['Data_Constellation'] + ' - ' + data['Task']

# TODO: drop unnecessary columns here
dc_unique = data.Data_Constellation_full.unique()
#print(dc_unique)

#data_constellations = ['MAR - 0.01', 'MAR - 0.1', 'MAR - 0.3', 'MCAR - 0.5', 'MCAR - 0.01', 'MCAR - 0.1', 'MCAR - 0.3', 'MCAR - 0.5', 'MNAR - 0.01', 'MNAR - 0.1', 'MNAR - 0.3', 'MNAR - 0.5']
data_constellations = dc_unique.tolist()
methods = ['Random Forest', 'KNN', 'Mean/Mode', 'VAE', 'GAIN', 'Discriminative DL']
#print(data_constellations)
#print(type(methods))
average_best_complete = pd.DataFrame()


for i in data_constellations:
    data_constel = data.loc[data['Data_Constellation_full'] == i]
    best_score = data_constel.loc[data_constel['Downstream Performance Rank'] == 1.0]
    average_best = data_constel.loc[data_constel['Imputation_Method'] == AVERAGE_BEST_IMPUTATION_METHOD]
    best_score_int = best_score.iloc[0]['Imputed']
    #print(best_score_int)
    average_best_int = average_best.iloc[0]['Imputed']
    #print(average_best_int)
    calc_result = ((best_score_int - average_best_int)/average_best_int)
#    print(calc_result)
#    print(i)
    average_best['Performance Difference to Best to Average in Percent'] = calc_result
    average_best_complete = average_best_complete.append(average_best)
    
    
    #conditions = [data['Data_Constellation_full'].eq(i) & data['Imputation_Method'].eq(AVERAGE_BEST_IMPUTATION_METHOD)]
    #choices = [calc_result]
    #data['Performance Difference to Best to Average in Percent'] = np.select(conditions, choices)#, default=np.nan)    

    #data['Performance Difference to Best to Average in Percent'] = calc_result

    
    #data.loc[data['Data_Constellation_full'] == i, data['Imputation_Method']==AVERAGE_BEST_IMPUTATION_METHOD, 'Performance Difference to Best to Average in Percent'] = calc_result 
    
#    data = np.where( ( (data['Data_Constellation_full'] == i) & (data['Imputation_Method'] == AVERAGE_BEST_IMPUTATION_METHOD ) ), calc_result, np.nan)


#test = data['Performance Difference to Best to Average in Percent'].mean()    
#print(test)
#data.to_csv("Performance Difference based on F1 Score.csv")    


#df=data.dropna(subset=['Performance Difference to Best to Average in Percent'])
#average_difference = df['Performance Difference to Best to Average in Percent'].mean()
#print(average_difference, "average difference")  
average_best_complete
# Out:
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/4148240555.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/4148240555.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#     Imputation_Method   Task Missing Type Missing Fraction Column  \
# 3                 KNN     30          MAR             0.01  eccen
# 7                 KNN     30          MAR              0.1  eccen
# 12                KNN     30          MAR              0.3  eccen
# 19                KNN     30          MAR              0.5  eccen
# 25                KNN     30         MCAR             0.01  eccen
# ..                ...    ...          ...              ...    ...
# 684               KNN  41671         MCAR              0.5     a9
# 691               KNN  41671         MNAR             0.01     a9
# 697               KNN  41671         MNAR              0.1     a9
# 701               KNN  41671         MNAR              0.3     a9
# 711               KNN  41671         MNAR              0.5     a9
#
#                      result_type    metric  Baseline  Corrupted   Imputed  \
# 3    downstream_performance_mean  F1_macro  0.702542        0.0  0.702542
# 7    downstream_performance_mean  F1_macro  0.674449        0.0  0.674449
# 12   downstream_performance_mean  F1_macro  0.647119        0.0  0.643422
# 19   downstream_performance_mean  F1_macro  0.714564        0.0  0.715378
# 25   downstream_performance_mean  F1_macro  0.713955        0.0  0.711018
# ..                           ...       ...       ...        ...       ...
# 684  downstream_performance_mean  F1_macro  0.237525        0.0  0.236969
# 691  downstream_performance_mean  F1_macro  0.240619        0.0  0.240619
# 697  downstream_performance_mean  F1_macro  0.240084        0.0  0.239984
# 701  downstream_performance_mean  F1_macro  0.239976        0.0  0.239941
# 711  downstream_performance_mean  F1_macro  0.264992        0.0  0.265395
#
#      ...  MinorityClassSize NumberOfFeatures  NumberOfInstances  \
# 3    ...               28.0             11.0             5473.0
# 7    ...               28.0             11.0             5473.0
# 12   ...               28.0             11.0             5473.0
# 19   ...               28.0             11.0             5473.0
# 25   ...               28.0             11.0             5473.0
# ..   ...                ...              ...                ...
# 684  ...              743.0             21.0            20000.0
# 691  ...              743.0             21.0            20000.0
# 697  ...              743.0             21.0            20000.0
# 701  ...              743.0             21.0            20000.0
# 711  ...              743.0             21.0            20000.0
#
#      NumberOfNumericFeatures  NumberOfCategoricalFeatures  NumberOfClasses  \
# 3                       10.0                          1.0              5.0
# 7                       10.0                          1.0              5.0
# 12                      10.0                          1.0              5.0
# 19                      10.0                          1.0              5.0
# 25                      10.0                          1.0              5.0
# ..                       ...                          ...              ...
# 684                     20.0                          1.0              5.0
# 691                     20.0                          1.0              5.0
# 697                     20.0                          1.0              5.0
# 701                     20.0                          1.0              5.0
# 711                     20.0                          1.0              5.0
#
#      Downstream Performance Rank  Data_Constellation  Data_Constellation_full  \
# 3                            3.0          MAR - 0.01          MAR - 0.01 - 30
# 7                            5.0           MAR - 0.1           MAR - 0.1 - 30
# 12                           6.0           MAR - 0.3           MAR - 0.3 - 30
# 19                           5.0           MAR - 0.5           MAR - 0.5 - 30
# 25                           5.0         MCAR - 0.01         MCAR - 0.01 - 30
# ..                           ...                 ...                      ...
# 684                          5.0          MCAR - 0.5       MCAR - 0.5 - 41671
# 691                          1.0         MNAR - 0.01      MNAR - 0.01 - 41671
# 697                          3.0          MNAR - 0.1       MNAR - 0.1 - 41671
# 701                          5.0          MNAR - 0.3       MNAR - 0.3 - 41671
# 711                          1.0          MNAR - 0.5       MNAR - 0.5 - 41671
#
#      Performance Difference to Best to Average in Percent
# 3                                             0.051033
# 7                                             0.103629
# 12                                            0.167532
# 19                                            0.052736
# 25                                            0.055940
# ..                                                 ...
# 684                                           0.035315
# 691                                           0.000000
# 697                                           0.008372
# 701                                           0.020850
# 711                                           0.000000
#
# [120 rows x 23 columns]

# %%
average_difference = average_best_complete['Performance Difference to Best to Average in Percent'].mean()
print(average_difference, "average difference in Percent")
# Out:
# 0.05903317877431598 average difference in Percent

# %%
# Relative Difference in absolute values (F1 Score) -> Best Method to Average Best Method

#AVERAGE_BEST_IMPUTATION_METHOD = "KNN"

data = downstream_results_rank.copy()
data['Task'] = data['Task'].astype(str)
data['Data_Constellation_full'] = data['Data_Constellation'] + ' - ' + data['Task']

# TODO: drop unnecessary columns here
dc_unique = data.Data_Constellation_full.unique()
#print(dc_unique)

#data_constellations = ['MAR - 0.01', 'MAR - 0.1', 'MAR - 0.3', 'MCAR - 0.5', 'MCAR - 0.01', 'MCAR - 0.1', 'MCAR - 0.3', 'MCAR - 0.5', 'MNAR - 0.01', 'MNAR - 0.1', 'MNAR - 0.3', 'MNAR - 0.5']
data_constellations = dc_unique.tolist()
methods = ['Random Forest', 'KNN', 'Mean/Mode', 'VAE', 'GAIN', 'Discriminative DL']
#print(data_constellations)
#print(type(methods))
average_best_total = pd.DataFrame()


for i in data_constellations:
    data_constel = data.loc[data['Data_Constellation_full'] == i]
    best_score = data_constel.loc[data_constel['Downstream Performance Rank'] == 1.0]
    average_best = data_constel.loc[data_constel['Imputation_Method'] == AVERAGE_BEST_IMPUTATION_METHOD]
    best_score_int = best_score.iloc[0]['Imputed']
    #print(best_score_int)
    average_best_int = average_best.iloc[0]['Imputed']
    #print(average_best_int)
    calc_result = (best_score_int - average_best_int)
#    print(calc_result)
#    print(i)
    average_best['Performance Difference to Best to Average in absolute'] = calc_result
    average_best_total = average_best_total.append(average_best)
 
average_best_total
# Out:
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/3130255045.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/3130255045.py:33: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#     Imputation_Method   Task Missing Type Missing Fraction Column  \
# 3                 KNN     30          MAR             0.01  eccen
# 7                 KNN     30          MAR              0.1  eccen
# 12                KNN     30          MAR              0.3  eccen
# 19                KNN     30          MAR              0.5  eccen
# 25                KNN     30         MCAR             0.01  eccen
# ..                ...    ...          ...              ...    ...
# 684               KNN  41671         MCAR              0.5     a9
# 691               KNN  41671         MNAR             0.01     a9
# 697               KNN  41671         MNAR              0.1     a9
# 701               KNN  41671         MNAR              0.3     a9
# 711               KNN  41671         MNAR              0.5     a9
#
#                      result_type    metric  Baseline  Corrupted   Imputed  \
# 3    downstream_performance_mean  F1_macro  0.702542        0.0  0.702542
# 7    downstream_performance_mean  F1_macro  0.674449        0.0  0.674449
# 12   downstream_performance_mean  F1_macro  0.647119        0.0  0.643422
# 19   downstream_performance_mean  F1_macro  0.714564        0.0  0.715378
# 25   downstream_performance_mean  F1_macro  0.713955        0.0  0.711018
# ..                           ...       ...       ...        ...       ...
# 684  downstream_performance_mean  F1_macro  0.237525        0.0  0.236969
# 691  downstream_performance_mean  F1_macro  0.240619        0.0  0.240619
# 697  downstream_performance_mean  F1_macro  0.240084        0.0  0.239984
# 701  downstream_performance_mean  F1_macro  0.239976        0.0  0.239941
# 711  downstream_performance_mean  F1_macro  0.264992        0.0  0.265395
#
#      ...  MinorityClassSize NumberOfFeatures  NumberOfInstances  \
# 3    ...               28.0             11.0             5473.0
# 7    ...               28.0             11.0             5473.0
# 12   ...               28.0             11.0             5473.0
# 19   ...               28.0             11.0             5473.0
# 25   ...               28.0             11.0             5473.0
# ..   ...                ...              ...                ...
# 684  ...              743.0             21.0            20000.0
# 691  ...              743.0             21.0            20000.0
# 697  ...              743.0             21.0            20000.0
# 701  ...              743.0             21.0            20000.0
# 711  ...              743.0             21.0            20000.0
#
#      NumberOfNumericFeatures  NumberOfCategoricalFeatures  NumberOfClasses  \
# 3                       10.0                          1.0              5.0
# 7                       10.0                          1.0              5.0
# 12                      10.0                          1.0              5.0
# 19                      10.0                          1.0              5.0
# 25                      10.0                          1.0              5.0
# ..                       ...                          ...              ...
# 684                     20.0                          1.0              5.0
# 691                     20.0                          1.0              5.0
# 697                     20.0                          1.0              5.0
# 701                     20.0                          1.0              5.0
# 711                     20.0                          1.0              5.0
#
#      Downstream Performance Rank  Data_Constellation  Data_Constellation_full  \
# 3                            3.0          MAR - 0.01          MAR - 0.01 - 30
# 7                            5.0           MAR - 0.1           MAR - 0.1 - 30
# 12                           6.0           MAR - 0.3           MAR - 0.3 - 30
# 19                           5.0           MAR - 0.5           MAR - 0.5 - 30
# 25                           5.0         MCAR - 0.01         MCAR - 0.01 - 30
# ..                           ...                 ...                      ...
# 684                          5.0          MCAR - 0.5       MCAR - 0.5 - 41671
# 691                          1.0         MNAR - 0.01      MNAR - 0.01 - 41671
# 697                          3.0          MNAR - 0.1       MNAR - 0.1 - 41671
# 701                          5.0          MNAR - 0.3       MNAR - 0.3 - 41671
# 711                          1.0          MNAR - 0.5       MNAR - 0.5 - 41671
#
#      Performance Difference to Best to Average in absolute
# 3                                             0.035853
# 7                                             0.069892
# 12                                            0.107794
# 19                                            0.037726
# 25                                            0.039774
# ..                                                 ...
# 684                                           0.008369
# 691                                           0.000000
# 697                                           0.002009
# 701                                           0.005003
# 711                                           0.000000
#
# [120 rows x 23 columns]

# %%
average_difference = average_best_total['Performance Difference to Best to Average in absolute'].mean()
print(average_difference, "average difference in absolut")
# Out:
# 0.015514683711449376 average difference in absolut

# %% [markdown]
# ## Heatmap (needs to be adjusted)

# %%
#df_heat = pd.read_csv('downstream_results_rank_temp.csv')
df_heat = downstream_results_rank.copy()
df_heat.drop(["Missing Type", "Missing Fraction", "Column", "result_type", "metric", "Baseline", "Corrupted", "Unnamed: 0", "Unnamed: 0", "name", "NumberOfClasses", "MajorityClassSize", "MinorityClassSize"], axis=1, inplace=True)
#df_heat['Improvement'] = df_heat['Improvement'] - 1
df_heat
# Out:
#      Imputation_Method   Task   Imputed  NumberOfFeatures  NumberOfInstances  \
# 0    Discriminative DL     30  0.673140              11.0             5473.0
# 1        Random Forest     30  0.674928              11.0             5473.0
# 2                 GAIN     30  0.681451              11.0             5473.0
# 3                  KNN     30  0.702542              11.0             5473.0
# 4            Mean/Mode     30  0.738240              11.0             5473.0
# ..                 ...    ...       ...               ...                ...
# 707  Discriminative DL  41671  0.240732              21.0            20000.0
# 708          Mean/Mode  41671  0.240780              21.0            20000.0
# 709                VAE  41671  0.242421              21.0            20000.0
# 710               GAIN  41671  0.243434              21.0            20000.0
# 711                KNN  41671  0.265395              21.0            20000.0
#
#      NumberOfNumericFeatures  NumberOfCategoricalFeatures  \
# 0                       10.0                          1.0
# 1                       10.0                          1.0
# 2                       10.0                          1.0
# 3                       10.0                          1.0
# 4                       10.0                          1.0
# ..                       ...                          ...
# 707                     20.0                          1.0
# 708                     20.0                          1.0
# 709                     20.0                          1.0
# 710                     20.0                          1.0
# 711                     20.0                          1.0
#
#      Downstream Performance Rank Data_Constellation
# 0                            6.0         MAR - 0.01
# 1                            5.0         MAR - 0.01
# 2                            4.0         MAR - 0.01
# 3                            3.0         MAR - 0.01
# 4                            2.0         MAR - 0.01
# ..                           ...                ...
# 707                          5.0         MNAR - 0.5
# 708                          4.0         MNAR - 0.5
# 709                          3.0         MNAR - 0.5
# 710                          2.0         MNAR - 0.5
# 711                          1.0         MNAR - 0.5
#
# [712 rows x 9 columns]

# %%
# Get a dataframe for each "Data_Constellation"
# Hier mit Variablen arbeiten -> Liste mit Konstellationen

# Hier eventuell for schleife, etc


# drop unneccessary columns

#df_heat = downstream_results_rank
#df_heat.drop(["Missing Type", "Missing Fraction", "Column", "result_type", "metric", "Baseline", "Imputed", "Corrupted", "Unnamed: 0", "Unnamed: 0", "name", "NumberOfClasses", "MajorityClassSize", "MinorityClassSize"], axis=1, inplace=True)

#df_heat['Improvement'] = df_heat['Improvement']
df_heat = df_heat.astype({"Task":"string"})

#mar001.drop(["Missing Type", "Missing Fraction", "Column", "result_type", "metric", "Baseline", "Imputed", "Corrupted", "Unnamed: 0"], axis=1, inplace=True)

data_constellations = ['MAR - 0.01', 'MAR - 0.1', 'MAR - 0.3', 'MCAR - 0.5', 'MCAR - 0.01', 'MCAR - 0.1', 'MCAR - 0.3', 'MCAR - 0.5', 'MNAR - 0.01', 'MNAR - 0.1', 'MNAR - 0.3', 'MNAR - 0.5']


for i in data_constellations:
    data_constel = df_heat.loc[df_heat['Data_Constellation'] == i]

    ### uncomment whatever you want to investigate

    ## sort by amount datapoints (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfInstances'])

    ## sort by amount of features (ascending)
    data_constel = data_constel.sort_values(by=['NumberOfFeatures'])

    ## sort by amount of datapoints and features (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfInstances', 'NumberOfFeatures'])

    ## sort by amount of categorical features and datapoints (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfCategoricalFeatures', 'NumberOfInstances'])

    ## sort by amount of numerical features and datapoints (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfNumericFeatures', 'NumberOfInstances'])
    
    Dataset_number = data_constel["Task"]
    Imputation_Method = data_constel["Imputation_Method"]
    F1_Score = data_constel["Imputed"]
    

    trace = go.Heatmap(
                   z=F1_Score,
                   x=Dataset_number,
                   y=Imputation_Method,
                   type = 'heatmap',
                    autocolorscale= False,
                    colorscale = 'Reds',
                    #zmid=0,
                    zmin=0,
                    #hoverinfo='text',
                    #text=hovertext
                    )
    data = [trace]
    fig = go.Figure(data=data)
    fig.update_layout(
        title=i,
        xaxis_nticks=36)
    fig.show()
# Out:
# <div>                            <div id="4734dce0-c897-4dbc-a5ac-9833389c10d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4734dce0-c897-4dbc-a5ac-9833389c10d7")) {                    Plotly.newPlot(                        "4734dce0-c897-4dbc-a5ac-9833389c10d7",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["1481","184","1481","184","184","184","1481","1481","1481","1481","41027","41027","41027","41027","41027","41027","184","184","183","183","183","183","183","183","40685","40685","40685","40685","40685","40685","30","30","30","30","30","30","40498","40498","40498","40498","40498","40498","32","32","32","32","32","32","41671","41671","41671","41671","41671","40677","40677","40677","40677","40677","40677"],"y":["Mean/Mode","Discriminative DL","GAIN","Mean/Mode","Random Forest","VAE","KNN","Random Forest","Discriminative DL","VAE","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","KNN","KNN","GAIN","GAIN","VAE","Mean/Mode","KNN","Random Forest","Discriminative DL","GAIN","Random Forest","Discriminative DL","Mean/Mode","KNN","VAE","Discriminative DL","Random Forest","GAIN","KNN","Mean/Mode","VAE","Random Forest","Discriminative DL","VAE","Mean/Mode","GAIN","KNN","GAIN","Mean/Mode","VAE","Discriminative DL","KNN","Random Forest","Random Forest","VAE","Mean/Mode","KNN","Discriminative DL","GAIN","Mean/Mode","Random Forest","Discriminative DL","KNN","VAE"],"z":[0.1800861659457188,0.2950238701062138,0.1798068521640632,0.2961403794670185,0.2985401616154322,0.3051408889618776,0.1785781125693148,0.1792241358705313,0.1796112984080884,0.1797226798285687,0.475010743381614,0.4753909511524433,0.4812603270930904,0.4817048852026425,0.4818852813171264,0.4820436111004424,0.2949680222670972,0.2938091132000425,0.1008473125633537,0.1025513902001184,0.102418395042972,0.1007966992633871,0.1007597251060761,0.1103146186504149,0.3813439678937736,0.3826628317704124,0.3826628317704124,0.3855875223617341,0.3951985156769521,0.3811266505908381,0.673139889273919,0.6749275814874108,0.6814505206763748,0.7025423288896501,0.7382401381734329,0.7383948990222624,0.1902652149063561,0.190765895361113,0.1916757341838165,0.1922959838050243,0.20693100953286,0.1739990273704833,0.9305770605438444,0.931158981730982,0.9311660695160828,0.9323596619720677,0.9326352333771616,0.9320743877494196,0.2406194774852596,0.2399943975793515,0.2400455762496122,0.2405430786215426,0.2406194774852596,0.7519449070662064,0.7518714681362714,0.7514217838412544,0.7509530021487891,0.7509349817297944,0.750120706866006],"zmin":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0," ...
# <div>                            <div id="6faaa19d-3a1d-4f4b-8986-ced507c7431f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6faaa19d-3a1d-4f4b-8986-ced507c7431f")) {                    Plotly.newPlot(                        "6faaa19d-3a1d-4f4b-8986-ced507c7431f",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["1481","184","1481","184","184","184","1481","1481","1481","1481","41027","41027","41027","41027","41027","41027","184","184","183","183","183","183","183","183","40685","40685","40685","40685","40685","40685","30","30","30","30","30","30","40498","40498","40498","40498","40498","40498","32","32","32","32","32","32","41671","41671","41671","41671","41671","41671","40677","40677","40677","40677","40677","40677"],"y":["KNN","KNN","GAIN","VAE","Mean/Mode","Random Forest","VAE","Mean/Mode","Discriminative DL","Random Forest","GAIN","KNN","Mean/Mode","Random Forest","Discriminative DL","VAE","Discriminative DL","GAIN","Random Forest","Mean/Mode","GAIN","Discriminative DL","KNN","VAE","Discriminative DL","KNN","Random Forest","GAIN","Mean/Mode","VAE","Random Forest","KNN","Discriminative DL","Mean/Mode","VAE","GAIN","Discriminative DL","VAE","KNN","Mean/Mode","GAIN","Random Forest","VAE","Discriminative DL","GAIN","Random Forest","KNN","Mean/Mode","KNN","Discriminative DL","VAE","Random Forest","GAIN","Mean/Mode","Random Forest","Discriminative DL","KNN","VAE","Mean/Mode","GAIN"],"z":[0.2048473956288976,0.2953396848484005,0.2042603381184814,0.2957052299222656,0.2966488244473005,0.3006957570964418,0.1975660217132124,0.1992183127309639,0.2013193175819976,0.2029013437283471,0.472977474681016,0.4731676720159346,0.4734529111538971,0.473488860517091,0.4737216760583944,0.5028213744001225,0.293944111774972,0.2830774629652035,0.1105069463231146,0.1119020094724602,0.1118447410582451,0.1103188772376971,0.1102118371644583,0.1169129368025304,0.3834146173615735,0.3853683756840227,0.3855221492587783,0.3864087490160675,0.3870440374499564,0.3821367054352677,0.673139889273919,0.674449366742874,0.6935672721668421,0.7316888727651739,0.7376625119771857,0.7443416834731829,0.2093624421827165,0.2105455840553135,0.210631781452407,0.2121566605673532,0.2673402218937353,0.1916838222090517,0.9294693896165904,0.929616165883338,0.929682714312039,0.9300481005193624,0.9320067800531572,0.9305684797102224,0.2454455226702901,0.2385358743642819,0.2398983313012012,0.240636801433911,0.241079712839226,0.2596950363035465,0.7428093941864745,0.7387377690501609,0.7337571253705818,0.7335786577253535,0.7329477605777587,0.73093151789155],"zmin":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"t ...
# <div>                            <div id="5b2645ee-8a32-478e-9776-9c5a72acc269" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b2645ee-8a32-478e-9776-9c5a72acc269")) {                    Plotly.newPlot(                        "5b2645ee-8a32-478e-9776-9c5a72acc269",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["1481","1481","1481","1481","184","184","184","184","184","184","1481","1481","41027","41027","41027","41027","41027","41027","183","183","183","183","183","183","40685","40685","40685","40685","40685","30","30","30","30","30","30","40498","40498","40498","40498","40498","40498","32","32","32","32","32","32","41671","41671","41671","41671","41671","41671","40677","40677","40677","40677","40677","40677"],"y":["GAIN","VAE","Random Forest","Discriminative DL","Random Forest","Discriminative DL","GAIN","Mean/Mode","KNN","VAE","KNN","Mean/Mode","Random Forest","Discriminative DL","KNN","VAE","Mean/Mode","GAIN","KNN","Discriminative DL","VAE","Mean/Mode","GAIN","Random Forest","GAIN","KNN","Random Forest","VAE","Mean/Mode","KNN","GAIN","Random Forest","Discriminative DL","Mean/Mode","VAE","KNN","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","VAE","Mean/Mode","Random Forest","GAIN","Discriminative DL","KNN","GAIN","Mean/Mode","Random Forest","VAE","Discriminative DL","KNN","GAIN","Discriminative DL","Mean/Mode","KNN","VAE","Random Forest"],"z":[0.2185957636736707,0.1756410840789096,0.1731212590382968,0.1696584261885639,0.2662203555642753,0.2576680975752809,0.2495140347433632,0.2491228818689311,0.2478664498860349,0.2413296091685182,0.1783556808718027,0.1866100110874324,0.4836114621435788,0.483195005834446,0.4809931966299325,0.4693995022525242,0.4681850745560701,0.4670407083913312,0.0993370730186637,0.1057844432400149,0.1282859120570658,0.11299576206706,0.1124747321291891,0.1009844278550857,0.3791278604225747,0.3915378852299938,0.390258749000574,0.3968699879257426,0.4058520432401741,0.6434215990654754,0.6809666172178487,0.7124987691572512,0.7323253126227954,0.7445432363890152,0.7512153836206057,0.1736898146154558,0.1872869348009274,0.1911245030003491,0.2232492152032537,0.2236720209481089,0.2487817049002327,0.9154969746190552,0.9216644256357348,0.9275758550527518,0.9277067925311973,0.9287514946153888,0.9324092523814588,0.2343106864305777,0.2396221094873991,0.2408010724331738,0.2416302877194058,0.2435007077803397,0.2621138132652903,0.7185588249240088,0.7181771415735166,0.7132282324183002,0.7112770401435036,0.7102273185577563,0.7072575561928761],"zmin":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"] ...
# <div>                            <div id="c2a0b406-d87e-4740-b0db-6aa1fe6416ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2a0b406-d87e-4740-b0db-6aa1fe6416ef")) {                    Plotly.newPlot(                        "c2a0b406-d87e-4740-b0db-6aa1fe6416ef",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["1481","184","1481","184","184","184","1481","1481","1481","1481","41027","41027","41027","41027","41027","41027","184","184","183","183","183","183","183","183","40685","40685","40685","40685","40685","40685","30","30","30","30","30","30","40498","40498","40498","40498","40498","40498","32","32","32","32","32","32","41671","41671","41671","41671","41671","41671","40677","40677","40677","40677","40677","40677"],"y":["VAE","KNN","Random Forest","GAIN","Mean/Mode","Discriminative DL","Discriminative DL","KNN","GAIN","Mean/Mode","GAIN","VAE","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Random Forest","Discriminative DL","Mean/Mode","KNN","GAIN","Random Forest","VAE","KNN","Mean/Mode","Discriminative DL","VAE","GAIN","Random Forest","Mean/Mode","VAE","Discriminative DL","KNN","GAIN","Random Forest","Discriminative DL","Random Forest","VAE","KNN","Mean/Mode","GAIN","VAE","Discriminative DL","GAIN","Mean/Mode","KNN","Random Forest","VAE","Discriminative DL","KNN","Mean/Mode","Random Forest","GAIN","Discriminative DL","Mean/Mode","KNN","Random Forest","VAE","GAIN"],"z":[0.2465430475542841,0.2391322515020217,0.2211957978608788,0.2495077483596283,0.2524391613283003,0.2583998898825999,0.1856450057734859,0.2121894876350148,0.2131660647527092,0.2195326463838594,0.4673440101469506,0.4692285711753841,0.4698965793902196,0.4710977764709967,0.4718279026671776,0.4722573018298408,0.2367729341094215,0.2334870110139734,0.1076161300439415,0.1185982659377012,0.1082845797081902,0.1044007098351249,0.09601198185247,0.1204625708337047,0.3813224187506533,0.3817469870743968,0.3819549528529997,0.3852909353995764,0.3904330503715315,0.3807478405835225,0.6435975858133407,0.7202565379088673,0.72426031856526,0.733106050374125,0.7386496168855641,0.7788052155156372,0.2047002385772129,0.2056154577745846,0.2056692027246418,0.2207568099186757,0.2222407009198354,0.1986153870895839,0.9179861127909632,0.9216638047806082,0.9230333534120196,0.926524470027731,0.92971542573209,0.9283767666794058,0.2428168175322341,0.2326198026508301,0.2369692384030182,0.2382776667122784,0.2404111312756811,0.2453378821508934,0.6867464798316522,0.679661881387029,0.6791159874190954,0.6790183041664379,0.6714478457456542,0.6650758586310593],"zmin":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0 ...
# <div>                            <div id="8bd1a8c4-8379-4a57-ae89-863a5febdb53" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8bd1a8c4-8379-4a57-ae89-863a5febdb53")) {                    Plotly.newPlot(                        "8bd1a8c4-8379-4a57-ae89-863a5febdb53",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["1481","184","1481","184","184","184","1481","1481","1481","1481","41027","41027","41027","41027","41027","41027","184","184","183","183","183","183","183","183","40685","40685","40685","40685","40685","40685","30","30","30","30","30","30","40498","40498","40498","40498","40498","40498","32","32","32","32","32","32","41671","41671","41671","41671","41671","40677","40677","40677","40677","40677","40677"],"y":["VAE","GAIN","Mean/Mode","Random Forest","VAE","KNN","Random Forest","GAIN","Discriminative DL","KNN","Discriminative DL","Mean/Mode","KNN","Random Forest","VAE","GAIN","Discriminative DL","Mean/Mode","Discriminative DL","Random Forest","KNN","GAIN","VAE","Mean/Mode","Mean/Mode","Random Forest","GAIN","KNN","VAE","Discriminative DL","Discriminative DL","KNN","GAIN","VAE","Random Forest","Mean/Mode","VAE","Discriminative DL","Random Forest","KNN","GAIN","Mean/Mode","Mean/Mode","Random Forest","VAE","KNN","GAIN","Discriminative DL","Random Forest","VAE","Mean/Mode","KNN","Discriminative DL","VAE","Random Forest","KNN","GAIN","Discriminative DL","Mean/Mode"],"z":[0.2070977600592616,0.2924151783143145,0.2058815705189672,0.2933504535522039,0.2988047536261471,0.3046900432065515,0.2044918135382728,0.2046592918789196,0.2047519387721331,0.2048853341576546,0.4747051423942672,0.4747272502004522,0.4747812933056909,0.4762305494313163,0.4769267196456913,0.477039921105884,0.2923831145295973,0.2875763788664974,0.1003814775329029,0.1007870312684314,0.1004181352158212,0.100358773428286,0.0978519246085159,0.1127640704264529,0.3826628317704124,0.3826628317704124,0.3851893120643747,0.385579602130894,0.3898769143707754,0.3826469914880009,0.673139889273919,0.7110181273037526,0.722701815170804,0.7332268786368509,0.7352940215399112,0.7507925065071271,0.1427472100586017,0.1809398986394352,0.1913432085480369,0.208720796215558,0.2341726734213262,0.1419417674334622,0.9305789490337348,0.9311738032415988,0.9312329035364504,0.9318251914076656,0.9326208909235508,0.9315374568648082,0.2406194774852596,0.2398792417980245,0.2400725133322066,0.2404667013720408,0.2406194774852596,0.7560009501061392,0.7539909662909273,0.7531803324386228,0.7529058668859637,0.7518506762541287,0.7492418734536144],"zmin":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0 ...
# <div>                            <div id="db6402ee-6c48-49f8-b30d-b94e57c9e2df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db6402ee-6c48-49f8-b30d-b94e57c9e2df")) {                    Plotly.newPlot(                        "db6402ee-6c48-49f8-b30d-b94e57c9e2df",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["1481","184","1481","184","184","184","1481","1481","1481","1481","41027","41027","41027","41027","41027","41027","184","184","183","183","183","183","183","183","40685","40685","40685","40685","40685","40685","30","30","30","30","30","30","40498","40498","40498","40498","40498","40498","32","32","32","32","32","32","41671","41671","41671","41671","41671","40677","40677","40677","40677","40677","40677"],"y":["GAIN","GAIN","VAE","Mean/Mode","Random Forest","VAE","Discriminative DL","KNN","Random Forest","Mean/Mode","VAE","Random Forest","Mean/Mode","Discriminative DL","KNN","GAIN","Discriminative DL","KNN","Discriminative DL","Random Forest","KNN","GAIN","VAE","Mean/Mode","Random Forest","Discriminative DL","GAIN","VAE","KNN","Mean/Mode","Discriminative DL","KNN","Mean/Mode","Random Forest","GAIN","VAE","Mean/Mode","VAE","Discriminative DL","KNN","Random Forest","GAIN","Mean/Mode","VAE","Discriminative DL","KNN","GAIN","Random Forest","Discriminative DL","Mean/Mode","VAE","KNN","Random Forest","VAE","Discriminative DL","Random Forest","KNN","Mean/Mode","GAIN"],"z":[0.2080798944874071,0.2736280296411957,0.1920402284172253,0.2760061448219642,0.2824915549763827,0.2863054661630919,0.1698205478536304,0.1710158312014631,0.1726793092551453,0.1835372293610623,0.4754158915799791,0.4770360468489354,0.4778759728804811,0.4820517589171877,0.4876829961247688,0.4883104518771972,0.2728527342327954,0.2678843991104827,0.1015683759646441,0.1084114139129233,0.1048262918348768,0.1013501639744814,0.0940811525799311,0.1087930936273556,0.3828713806869001,0.3828713806869001,0.3845431041279645,0.392838130041544,0.3986463173315606,0.3828713806869001,0.6333567909922591,0.6533034671045866,0.7265974969487576,0.7381816016372452,0.7453150158539787,0.7652449694451483,0.1692877710066781,0.1704773859401487,0.1744796612551497,0.2068881411869978,0.2335737908302719,0.1648253809776054,0.927036347759056,0.9295162175888736,0.9295567878044478,0.9315947786859552,0.9320238103303876,0.9305639884944984,0.240415159393827,0.2292100435284936,0.2312926312163416,0.2391610322662891,0.2406194774852596,0.7401808645705756,0.7369970257201323,0.7363426610277929,0.7361743980280858,0.7355049080147807,0.733616124448857],"zmin":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0 ...
# <div>                            <div id="f6737c45-a601-4046-9b22-b93dc35b85fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6737c45-a601-4046-9b22-b93dc35b85fc")) {                    Plotly.newPlot(                        "f6737c45-a601-4046-9b22-b93dc35b85fc",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["1481","184","1481","184","184","184","1481","1481","1481","1481","41027","41027","41027","41027","41027","41027","184","184","183","183","183","183","183","183","40685","40685","40685","40685","40685","40685","30","30","30","30","30","30","40498","40498","40498","40498","40498","40498","32","32","32","32","32","32","41671","41671","41671","41671","41671","41671","40677","40677","40677","40677","40677","40677"],"y":["Discriminative DL","GAIN","Random Forest","Discriminative DL","Mean/Mode","Random Forest","KNN","Mean/Mode","GAIN","VAE","Discriminative DL","Random Forest","KNN","VAE","GAIN","Mean/Mode","VAE","KNN","Random Forest","Mean/Mode","VAE","KNN","Discriminative DL","GAIN","Discriminative DL","KNN","VAE","GAIN","Mean/Mode","Random Forest","Mean/Mode","KNN","Random Forest","Discriminative DL","VAE","GAIN","Mean/Mode","VAE","Discriminative DL","KNN","GAIN","Random Forest","VAE","Discriminative DL","GAIN","Mean/Mode","KNN","Random Forest","Random Forest","GAIN","KNN","Mean/Mode","Discriminative DL","VAE","KNN","Mean/Mode","Discriminative DL","GAIN","VAE","Random Forest"],"z":[0.2137535027903025,0.249197518738744,0.2086280305735216,0.2528541034260681,0.2564871315490873,0.2578611003532479,0.194778109406806,0.2003317677743266,0.2024782371738126,0.2032977236623605,0.4704582141760161,0.4726205561312714,0.4727389600164389,0.4729171033312593,0.4779545047867295,0.4884236714091114,0.2431601202515283,0.2271695384763575,0.1070496666443925,0.1084830519970061,0.1072409282583495,0.1053146033811147,0.1038529804100399,0.1087634672501041,0.3844404076920774,0.3920597254093057,0.3937604758615573,0.3947184206023195,0.4009730456912402,0.3789959054964162,0.6073356679702984,0.6683500425171824,0.6865754522084838,0.6898743788432737,0.6918749959545499,0.7499873689574542,0.1668979152586321,0.1696446404752694,0.1805301518001406,0.195503950429019,0.2207557793718409,0.1419358417080984,0.9199539802643218,0.9251785902652572,0.9252862614684052,0.9279087503919116,0.9307764002289596,0.9301964040168972,0.2405776103864901,0.2332841516765302,0.2346157315540725,0.2386300063684237,0.2405193277736428,0.2408774139185915,0.7251658479556425,0.7198958311430418,0.7165543837271476,0.7162886862366804,0.7118275600625972,0.7105919129251798],"zmin":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewi ...
# <div>                            <div id="741171c1-f326-45e2-8507-18b38470d467" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("741171c1-f326-45e2-8507-18b38470d467")) {                    Plotly.newPlot(                        "741171c1-f326-45e2-8507-18b38470d467",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["1481","184","1481","184","184","184","1481","1481","1481","1481","41027","41027","41027","41027","41027","41027","184","184","183","183","183","183","183","183","40685","40685","40685","40685","40685","40685","30","30","30","30","30","30","40498","40498","40498","40498","40498","40498","32","32","32","32","32","32","41671","41671","41671","41671","41671","41671","40677","40677","40677","40677","40677","40677"],"y":["VAE","KNN","Random Forest","GAIN","Mean/Mode","Discriminative DL","Discriminative DL","KNN","GAIN","Mean/Mode","GAIN","VAE","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Random Forest","Discriminative DL","Mean/Mode","KNN","GAIN","Random Forest","VAE","KNN","Mean/Mode","Discriminative DL","VAE","GAIN","Random Forest","Mean/Mode","VAE","Discriminative DL","KNN","GAIN","Random Forest","Discriminative DL","Random Forest","VAE","KNN","Mean/Mode","GAIN","VAE","Discriminative DL","GAIN","Mean/Mode","KNN","Random Forest","VAE","Discriminative DL","KNN","Mean/Mode","Random Forest","GAIN","Discriminative DL","Mean/Mode","KNN","Random Forest","VAE","GAIN"],"z":[0.2465430475542841,0.2391322515020217,0.2211957978608788,0.2495077483596283,0.2524391613283003,0.2583998898825999,0.1856450057734859,0.2121894876350148,0.2131660647527092,0.2195326463838594,0.4673440101469506,0.4692285711753841,0.4698965793902196,0.4710977764709967,0.4718279026671776,0.4722573018298408,0.2367729341094215,0.2334870110139734,0.1076161300439415,0.1185982659377012,0.1082845797081902,0.1044007098351249,0.09601198185247,0.1204625708337047,0.3813224187506533,0.3817469870743968,0.3819549528529997,0.3852909353995764,0.3904330503715315,0.3807478405835225,0.6435975858133407,0.7202565379088673,0.72426031856526,0.733106050374125,0.7386496168855641,0.7788052155156372,0.2047002385772129,0.2056154577745846,0.2056692027246418,0.2207568099186757,0.2222407009198354,0.1986153870895839,0.9179861127909632,0.9216638047806082,0.9230333534120196,0.926524470027731,0.92971542573209,0.9283767666794058,0.2428168175322341,0.2326198026508301,0.2369692384030182,0.2382776667122784,0.2404111312756811,0.2453378821508934,0.6867464798316522,0.679661881387029,0.6791159874190954,0.6790183041664379,0.6714478457456542,0.6650758586310593],"zmin":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0 ...
# <div>                            <div id="307919d5-421a-4020-9f48-38b1667b34ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("307919d5-421a-4020-9f48-38b1667b34ac")) {                    Plotly.newPlot(                        "307919d5-421a-4020-9f48-38b1667b34ac",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["1481","1481","184","184","184","184","184","184","1481","1481","1481","41027","41027","41027","41027","41027","1481","183","183","183","183","183","183","40685","40685","40685","40685","30","30","30","30","30","30","40498","40498","40498","40498","40498","40498","32","32","32","32","32","32","41671","41671","41671","41671","41671","40677","40677","40677","40677","40677","40677"],"y":["KNN","VAE","VAE","GAIN","Mean/Mode","Random Forest","Discriminative DL","KNN","Discriminative DL","Mean/Mode","Random Forest","VAE","Discriminative DL","Mean/Mode","KNN","Random Forest","GAIN","Mean/Mode","Discriminative DL","GAIN","Random Forest","KNN","VAE","KNN","Mean/Mode","Random Forest","VAE","VAE","Random Forest","Discriminative DL","KNN","GAIN","Mean/Mode","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","GAIN","Mean/Mode","VAE","Random Forest","VAE","KNN","Mean/Mode","Discriminative DL","Random Forest","KNN","Random Forest","VAE","Mean/Mode","GAIN","Discriminative DL"],"z":[0.1860396217972071,0.177865468539308,0.3031913866579481,0.2987424358914904,0.2979323287614574,0.2977800066361106,0.297636414379905,0.2957388913852161,0.1786773952287865,0.2063669994745482,0.1848067205288297,0.4746030866376364,0.4746702503808572,0.4746797322738925,0.4746992387604158,0.4748477149169429,0.2069038055107178,0.1042132786836628,0.1107622827974232,0.110924465553184,0.1112388768383422,0.1113356779551749,0.1106584734051914,0.3828641124984329,0.3831424629074784,0.3860334820749675,0.3934703415191711,0.6513025357791732,0.6808624480020361,0.6954722920071864,0.673139889273919,0.6756434971026503,0.6756434971026503,0.1902712227184507,0.1909479949695988,0.1913187171271796,0.1969945698237513,0.1970492584337743,0.2298313127128894,0.9282847736757526,0.930885939576898,0.9322743611701308,0.9328862720655908,0.932558400229099,0.93253597965611,0.2403192388995374,0.2406194774852596,0.2404471572163977,0.2406194774852596,0.2406194774852596,0.7525659585709494,0.7520734868620645,0.751681495985434,0.75089151210544,0.7502035627048729,0.7530647287063953],"zmin":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.444444444444 ...
# <div>                            <div id="0802f952-de31-4532-b563-832500c712ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0802f952-de31-4532-b563-832500c712ed")) {                    Plotly.newPlot(                        "0802f952-de31-4532-b563-832500c712ed",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["1481","184","1481","184","184","184","1481","1481","1481","1481","41027","41027","41027","41027","41027","41027","184","184","183","183","183","183","183","183","40685","40685","40685","40685","40685","40685","30","30","30","30","30","30","40498","40498","40498","40498","40498","40498","32","32","32","32","32","32","41671","41671","41671","41671","41671","41671","40677","40677","40677","40677","40677","40677"],"y":["KNN","Discriminative DL","VAE","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","GAIN","Mean/Mode","GAIN","Random Forest","Mean/Mode","KNN","Discriminative DL","VAE","KNN","Random Forest","Random Forest","GAIN","Mean/Mode","KNN","Discriminative DL","VAE","Mean/Mode","Random Forest","VAE","KNN","Discriminative DL","GAIN","VAE","Mean/Mode","Discriminative DL","GAIN","Random Forest","KNN","VAE","GAIN","KNN","Discriminative DL","Random Forest","Mean/Mode","VAE","Mean/Mode","Random Forest","KNN","GAIN","Discriminative DL","Random Forest","Mean/Mode","VAE","GAIN","KNN","Discriminative DL","Random Forest","Discriminative DL","VAE","KNN","GAIN","Mean/Mode"],"z":[0.2062338933711184,0.2760140280172119,0.1969391829764836,0.2788498742907505,0.2806029749089544,0.2851893115992809,0.1709988224491471,0.1838124982500295,0.1885010552576994,0.1914953490213746,0.4741328467369337,0.4748007871845725,0.4763220922538311,0.4781882127624144,0.4784069969755853,0.500477294112084,0.2747293921327362,0.2636351251918857,0.1013273280908327,0.1065386758055679,0.1051399766555877,0.1012573866078413,0.100834619853585,0.1183771794454756,0.3814931991358262,0.3827097494492745,0.3841093673554378,0.3842491893228389,0.3850987596531011,0.3807529409855106,0.6730742441029912,0.6741082967850304,0.674449366742874,0.7035848455231118,0.7449469743983766,0.7493689813241772,0.1852416931765844,0.1877188941347622,0.2214829627455131,0.2231311925928956,0.2333532215848512,0.1637332212360889,0.9266011252865812,0.9274852353327324,0.9299262842264172,0.9316039305530062,0.9322485033589524,0.9316424745656516,0.2406194774852596,0.2340342072275915,0.2349042065711534,0.2370694022576329,0.2399844353985176,0.2419936681732196,0.7509770013689391,0.7427056883076637,0.7390116751464014,0.7373969450827259,0.7313098051877219,0.7242450006567586],"zmin":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewi ...
# <div>                            <div id="0b0bc4b5-5457-40ed-ae91-f43039949919" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b0bc4b5-5457-40ed-ae91-f43039949919")) {                    Plotly.newPlot(                        "0b0bc4b5-5457-40ed-ae91-f43039949919",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["1481","184","1481","184","184","184","1481","1481","1481","1481","41027","41027","41027","41027","41027","41027","184","184","183","183","183","183","183","183","40685","40685","40685","40685","40685","40685","30","30","30","30","30","30","40498","40498","40498","40498","40498","40498","32","32","32","32","32","32","41671","41671","41671","41671","41671","41671","40677","40677","40677","40677","40677","40677"],"y":["KNN","GAIN","Mean/Mode","Random Forest","Discriminative DL","Mean/Mode","Discriminative DL","Random Forest","VAE","GAIN","Mean/Mode","GAIN","Discriminative DL","Random Forest","KNN","VAE","KNN","VAE","KNN","VAE","Discriminative DL","Random Forest","Mean/Mode","GAIN","Random Forest","KNN","VAE","GAIN","Discriminative DL","Mean/Mode","KNN","VAE","Discriminative DL","Random Forest","Mean/Mode","GAIN","VAE","GAIN","Mean/Mode","Random Forest","KNN","Discriminative DL","VAE","Mean/Mode","Discriminative DL","Random Forest","KNN","GAIN","Discriminative DL","VAE","KNN","GAIN","Random Forest","Mean/Mode","Mean/Mode","KNN","Random Forest","VAE","GAIN","Discriminative DL"],"z":[0.2277956203886607,0.25530027010104,0.2124782440589991,0.257790942598936,0.2593534317649809,0.2707090636972294,0.1948368478547382,0.1952051177893905,0.1959839176421416,0.2083844672301524,0.4720219485329737,0.4731187658623005,0.4738041585785498,0.474728194421634,0.4822907292868274,0.4877458946092134,0.2419867180608375,0.2183725665591713,0.0987005485333424,0.1136923034127437,0.1037021307967861,0.0984981608590314,0.0981598553814103,0.1246834410202537,0.3814787422819511,0.3824575385665684,0.3849935928256476,0.394556077901103,0.3954938231813866,0.3808054872677035,0.673139889273919,0.6765429384892715,0.6808624480020361,0.7093360883260585,0.7095038579935197,0.7129434181941846,0.2035523599367171,0.214227660986298,0.2223718871752493,0.2243000422581595,0.2413954044442617,0.1773826386887966,0.8394481671270154,0.8997921093085925,0.9227684282561488,0.9249284109115328,0.9289331525413193,0.9250430366394824,0.2411494653392425,0.2349042839624652,0.2399407098723334,0.2405709994340092,0.2406194774852596,0.2449434099666401,0.7240424957615015,0.7209635090329117,0.7122367200085261,0.707285236743597,0.7038439625926554,0.6841143137793327],"zmin":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth": ...
# <div>                            <div id="dbf3f42c-1867-4642-a322-411ccefda51f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dbf3f42c-1867-4642-a322-411ccefda51f")) {                    Plotly.newPlot(                        "dbf3f42c-1867-4642-a322-411ccefda51f",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["1481","184","1481","184","184","184","1481","1481","1481","1481","41027","41027","41027","41027","41027","41027","184","184","183","183","183","183","183","183","40685","40685","40685","40685","40685","40685","30","30","30","30","30","30","40498","40498","40498","40498","40498","40498","32","32","32","32","32","32","41671","41671","41671","41671","41671","41671","40677","40677","40677","40677","40677","40677"],"y":["Discriminative DL","VAE","KNN","Discriminative DL","GAIN","Mean/Mode","GAIN","Mean/Mode","Random Forest","VAE","GAIN","VAE","Discriminative DL","Mean/Mode","Random Forest","KNN","Random Forest","KNN","Discriminative DL","KNN","VAE","GAIN","Random Forest","Mean/Mode","Mean/Mode","Random Forest","KNN","GAIN","VAE","Discriminative DL","VAE","GAIN","Discriminative DL","KNN","Random Forest","Mean/Mode","KNN","Random Forest","Discriminative DL","VAE","Mean/Mode","GAIN","Mean/Mode","GAIN","VAE","Discriminative DL","KNN","Random Forest","GAIN","Random Forest","Discriminative DL","Mean/Mode","VAE","KNN","Random Forest","Discriminative DL","VAE","GAIN","KNN","Mean/Mode"],"z":[0.2083039335568138,0.2280205263988435,0.2082143168829281,0.2319360648732652,0.2402522895356217,0.2495460986626816,0.1897898548620772,0.200151206597904,0.2009045191740277,0.204037109329488,0.4671943994253964,0.4728634788841301,0.4765263286735215,0.4779385758236461,0.4907632465429385,0.4971383228454187,0.2254114361122322,0.2035892799300134,0.1030669163465494,0.1134288795771401,0.1083162851608471,0.0997259350508014,0.0957185703893472,0.1282568564687748,0.3831266465857821,0.384153631246662,0.38452963852217,0.3857275937022942,0.3952849540864425,0.3828488067478788,0.6885704679148783,0.690074774530471,0.6906706744241639,0.7280259915447589,0.728181183352123,0.7463880105848383,0.1950102457471555,0.1965552655336921,0.2053610200464432,0.2066138110748174,0.2184532865656336,0.1800080934120916,0.9005533451100142,0.908592683097674,0.9144117803581612,0.923151961341238,0.9268527528776443,0.9241826903044756,0.2434343929849736,0.2406194774852596,0.2407318083288237,0.240779660866085,0.2424209308365948,0.2653949918373737,0.7163798135436856,0.705105806467564,0.6955160584358797,0.6936420922031594,0.6799232490832744,0.6552963210259877],"zmin":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0," ...

# %%
downstream_results_rank_heatmap2
# Out:
#      Imputation_Method   Task Missing Type Missing Fraction Column  \
# 0    Discriminative DL     30          MAR             0.01  eccen
# 1        Random Forest     30          MAR             0.01  eccen
# 2                 GAIN     30          MAR             0.01  eccen
# 3                  KNN     30          MAR             0.01  eccen
# 4            Mean/Mode     30          MAR             0.01  eccen
# ..                 ...    ...          ...              ...    ...
# 707  Discriminative DL  41671         MNAR              0.5     a9
# 708          Mean/Mode  41671         MNAR              0.5     a9
# 709                VAE  41671         MNAR              0.5     a9
# 710               GAIN  41671         MNAR              0.5     a9
# 711                KNN  41671         MNAR              0.5     a9
#
#                      result_type    metric  Baseline  Corrupted   Imputed  \
# 0    downstream_performance_mean  F1_macro  0.673140        0.0  0.673140
# 1    downstream_performance_mean  F1_macro  0.674928        0.0  0.674928
# 2    downstream_performance_mean  F1_macro  0.681451        0.0  0.681451
# 3    downstream_performance_mean  F1_macro  0.702542        0.0  0.702542
# 4    downstream_performance_mean  F1_macro  0.738395        0.0  0.738240
# ..                           ...       ...       ...        ...       ...
# 707  downstream_performance_mean  F1_macro  0.240118        0.0  0.240732
# 708  downstream_performance_mean  F1_macro  0.239275        0.0  0.240780
# 709  downstream_performance_mean  F1_macro  0.241995        0.0  0.242421
# 710  downstream_performance_mean  F1_macro  0.239877        0.0  0.243434
# 711  downstream_performance_mean  F1_macro  0.264992        0.0  0.265395
#
#      ...               name MajorityClassSize  MinorityClassSize  \
# 0    ...        page-blocks            4913.0               28.0
# 1    ...        page-blocks            4913.0               28.0
# 2    ...        page-blocks            4913.0               28.0
# 3    ...        page-blocks            4913.0               28.0
# 4    ...        page-blocks            4913.0               28.0
# ..   ...                ...               ...                ...
# 707  ...  microaggregation2           11162.0              743.0
# 708  ...  microaggregation2           11162.0              743.0
# 709  ...  microaggregation2           11162.0              743.0
# 710  ...  microaggregation2           11162.0              743.0
# 711  ...  microaggregation2           11162.0              743.0
#
#      NumberOfFeatures  NumberOfInstances  NumberOfNumericFeatures  \
# 0                11.0             5473.0                     10.0
# 1                11.0             5473.0                     10.0
# 2                11.0             5473.0                     10.0
# 3                11.0             5473.0                     10.0
# 4                11.0             5473.0                     10.0
# ..                ...                ...                      ...
# 707              21.0            20000.0                     20.0
# 708              21.0            20000.0                     20.0
# 709              21.0            20000.0                     20.0
# 710              21.0            20000.0                     20.0
# 711              21.0            20000.0                     20.0
#
#      NumberOfCategoricalFeatures  NumberOfClasses  \
# 0                            1.0              5.0
# 1                            1.0              5.0
# 2                            1.0              5.0
# 3                            1.0              5.0
# 4                            1.0              5.0
# ..                           ...              ...
# 707                          1.0              5.0
# 708                          1.0              5.0
# 709                          1.0              5.0
# 710                          1.0              5.0
# 711                          1.0              5.0
#
#      Downstream Performance Rank  Data_Constellation
# 0                            6.0          MAR - 0.01
# 1                            5.0          MAR - 0.01
# 2                            4.0          MAR - 0.01
# 3                            3.0          MAR - 0.01
# 4                            2.0          MAR - 0.01
# ..                           ...                 ...
# 707                          5.0          MNAR - 0.5
# 708                          4.0          MNAR - 0.5
# 709                          3.0          MNAR - 0.5
# 710                          2.0          MNAR - 0.5
# 711                          1.0          MNAR - 0.5
#
# [712 rows x 21 columns]

# %%
#df_heat = pd.read_csv('downstream_results_rank_temp.csv')
df_heat_dif = downstream_results_rank_heatmap2
df_heat_dif.drop(["Missing Type", "Missing Fraction", "Column", "result_type", "metric", "Baseline", "Corrupted", "Unnamed: 0", "Unnamed: 0", "name", "NumberOfClasses", "MajorityClassSize", "MinorityClassSize"], axis=1, inplace=True)
#df_heat['Improvement'] = df_heat['Improvement'] - 1
df_heat_dif
# Out:
#      Imputation_Method   Task   Imputed  NumberOfFeatures  NumberOfInstances  \
# 0    Discriminative DL     30  0.673140              11.0             5473.0
# 1        Random Forest     30  0.674928              11.0             5473.0
# 2                 GAIN     30  0.681451              11.0             5473.0
# 3                  KNN     30  0.702542              11.0             5473.0
# 4            Mean/Mode     30  0.738240              11.0             5473.0
# ..                 ...    ...       ...               ...                ...
# 707  Discriminative DL  41671  0.240732              21.0            20000.0
# 708          Mean/Mode  41671  0.240780              21.0            20000.0
# 709                VAE  41671  0.242421              21.0            20000.0
# 710               GAIN  41671  0.243434              21.0            20000.0
# 711                KNN  41671  0.265395              21.0            20000.0
#
#      NumberOfNumericFeatures  NumberOfCategoricalFeatures  \
# 0                       10.0                          1.0
# 1                       10.0                          1.0
# 2                       10.0                          1.0
# 3                       10.0                          1.0
# 4                       10.0                          1.0
# ..                       ...                          ...
# 707                     20.0                          1.0
# 708                     20.0                          1.0
# 709                     20.0                          1.0
# 710                     20.0                          1.0
# 711                     20.0                          1.0
#
#      Downstream Performance Rank Data_Constellation
# 0                            6.0         MAR - 0.01
# 1                            5.0         MAR - 0.01
# 2                            4.0         MAR - 0.01
# 3                            3.0         MAR - 0.01
# 4                            2.0         MAR - 0.01
# ..                           ...                ...
# 707                          5.0         MNAR - 0.5
# 708                          4.0         MNAR - 0.5
# 709                          3.0         MNAR - 0.5
# 710                          2.0         MNAR - 0.5
# 711                          1.0         MNAR - 0.5
#
# [712 rows x 9 columns]

# %%
#Calculate Difference for every Imputation towards average best Imputation Method per Data Constellation

# Relative Difference in Percent -> Best Method to Average Best Method

#AVERAGE_BEST_IMPUTATION_METHOD = "KNN"

data = downstream_results_rank
data['Task'] = data['Task'].astype(str)
data['Data_Constellation_full'] = data['Data_Constellation'] + ' - ' + data['Task']

# TODO: drop unnecessary columns here
dc_unique = data.Data_Constellation_full.unique()
#print(dc_unique)

#data_constellations = ['MAR - 0.01', 'MAR - 0.1', 'MAR - 0.3', 'MCAR - 0.5', 'MCAR - 0.01', 'MCAR - 0.1', 'MCAR - 0.3', 'MCAR - 0.5', 'MNAR - 0.01', 'MNAR - 0.1', 'MNAR - 0.3', 'MNAR - 0.5']
data_constellations = dc_unique.tolist()

# EXCLUDE AVERAGE BEST FROM THIS LIST
#methods = ['KNN', 'Mean/Mode', 'VAE', 'GAIN', 'Discriminative DL']
methods = ['Random Forest', 'KNN', 'Mean/Mode', 'VAE', 'GAIN', 'Discriminative DL']

heatmap_data_difference = pd.DataFrame()


for i in data_constellations:
    data_constel = data.loc[data['Data_Constellation_full'] == i]
#    best_score = data_constel.loc[data_constel['Downstream Performance Rank'] == 1.0]
    average_best = data_constel.loc[data_constel['Imputation_Method'] == AVERAGE_BEST_IMPUTATION_METHOD]
    dataset_number = best_score.iloc[0]['Task']
    #print(dataset_number)
    for i in methods:
        if ((data_constel['Imputation_Method'] == i).any()):
            current_score_row = data_constel.loc[data['Imputation_Method'] == i]
            current_score_int = current_score_row.iloc[0]['Imputed']

        #print(best_score_int)
            average_best_int = average_best.iloc[0]['Imputed']

        #print(average_best_int)
            calc_result = (current_score_int - average_best_int)

    #    print(calc_result)
    #    print(i)
            current_score_row['Performance Difference to Average Best'] = calc_result
            heatmap_data_difference = heatmap_data_difference.append(current_score_row)  
        else:
            print("Imputation Method not here ---------------------")

heatmap_data_difference
# Out:
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_2178373/1497250884.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2178373/1497250884.py:45: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# Imputation Method not here ---------------------
# Imputation Method not here ---------------------
# Imputation Method not here ---------------------
# Imputation Method not here ---------------------
# Imputation Method not here ---------------------
# Imputation Method not here ---------------------
# Imputation Method not here ---------------------
# Imputation Method not here ---------------------
#      Imputation_Method   Task Missing Type Missing Fraction Column  \
# 1        Random Forest     30          MAR             0.01  eccen
# 3                  KNN     30          MAR             0.01  eccen
# 4            Mean/Mode     30          MAR             0.01  eccen
# 5                  VAE     30          MAR             0.01  eccen
# 2                 GAIN     30          MAR             0.01  eccen
# ..                 ...    ...          ...              ...    ...
# 711                KNN  41671         MNAR              0.5     a9
# 708          Mean/Mode  41671         MNAR              0.5     a9
# 709                VAE  41671         MNAR              0.5     a9
# 710               GAIN  41671         MNAR              0.5     a9
# 707  Discriminative DL  41671         MNAR              0.5     a9
#
#                      result_type    metric  Baseline  Corrupted   Imputed  \
# 1    downstream_performance_mean  F1_macro  0.674928        0.0  0.674928
# 3    downstream_performance_mean  F1_macro  0.702542        0.0  0.702542
# 4    downstream_performance_mean  F1_macro  0.738395        0.0  0.738240
# 5    downstream_performance_mean  F1_macro  0.738395        0.0  0.738395
# 2    downstream_performance_mean  F1_macro  0.681451        0.0  0.681451
# ..                           ...       ...       ...        ...       ...
# 711  downstream_performance_mean  F1_macro  0.264992        0.0  0.265395
# 708  downstream_performance_mean  F1_macro  0.239275        0.0  0.240780
# 709  downstream_performance_mean  F1_macro  0.241995        0.0  0.242421
# 710  downstream_performance_mean  F1_macro  0.239877        0.0  0.243434
# 707  downstream_performance_mean  F1_macro  0.240118        0.0  0.240732
#
#      ...  MinorityClassSize NumberOfFeatures  NumberOfInstances  \
# 1    ...               28.0             11.0             5473.0
# 3    ...               28.0             11.0             5473.0
# 4    ...               28.0             11.0             5473.0
# 5    ...               28.0             11.0             5473.0
# 2    ...               28.0             11.0             5473.0
# ..   ...                ...              ...                ...
# 711  ...              743.0             21.0            20000.0
# 708  ...              743.0             21.0            20000.0
# 709  ...              743.0             21.0            20000.0
# 710  ...              743.0             21.0            20000.0
# 707  ...              743.0             21.0            20000.0
#
#      NumberOfNumericFeatures  NumberOfCategoricalFeatures  NumberOfClasses  \
# 1                       10.0                          1.0              5.0
# 3                       10.0                          1.0              5.0
# 4                       10.0                          1.0              5.0
# 5                       10.0                          1.0              5.0
# 2                       10.0                          1.0              5.0
# ..                       ...                          ...              ...
# 711                     20.0                          1.0              5.0
# 708                     20.0                          1.0              5.0
# 709                     20.0                          1.0              5.0
# 710                     20.0                          1.0              5.0
# 707                     20.0                          1.0              5.0
#
#      Downstream Performance Rank  Data_Constellation  Data_Constellation_full  \
# 1                            5.0          MAR - 0.01          MAR - 0.01 - 30
# 3                            3.0          MAR - 0.01          MAR - 0.01 - 30
# 4                            2.0          MAR - 0.01          MAR - 0.01 - 30
# 5                            1.0          MAR - 0.01          MAR - 0.01 - 30
# 2                            4.0          MAR - 0.01          MAR - 0.01 - 30
# ..                           ...                 ...                      ...
# 711                          1.0          MNAR - 0.5       MNAR - 0.5 - 41671
# 708                          4.0          MNAR - 0.5       MNAR - 0.5 - 41671
# 709                          3.0          MNAR - 0.5       MNAR - 0.5 - 41671
# 710                          2.0          MNAR - 0.5       MNAR - 0.5 - 41671
# 707                          5.0          MNAR - 0.5       MNAR - 0.5 - 41671
#
#      Performance Difference to Average Best
# 1                                 -0.027615
# 3                                  0.000000
# 4                                  0.035698
# 5                                  0.035853
# 2                                 -0.021092
# ..                                      ...
# 711                                0.000000
# 708                               -0.024615
# 709                               -0.022974
# 710                               -0.021961
# 707                               -0.024663
#
# [712 rows x 23 columns]

# %%
# Get a dataframe for each "Data_Constellation"
# Hier mit Variablen arbeiten -> Liste mit Konstellationen

# Hier eventuell for schleife, etc


# drop unneccessary columns

#df_heat = downstream_results_rank
#df_heat.drop(["Missing Type", "Missing Fraction", "Column", "result_type", "metric", "Baseline", "Imputed", "Corrupted", "Unnamed: 0", "Unnamed: 0", "name", "NumberOfClasses", "MajorityClassSize", "MinorityClassSize"], axis=1, inplace=True)

#df_heat['Improvement'] = df_heat['Improvement']
heatmap_data_difference = heatmap_data_difference.astype({"Task":"string"})

#mar001.drop(["Missing Type", "Missing Fraction", "Column", "result_type", "metric", "Baseline", "Imputed", "Corrupted", "Unnamed: 0"], axis=1, inplace=True)

data_constellations = ['MAR - 0.01', 'MAR - 0.1', 'MAR - 0.3', 'MCAR - 0.5', 'MCAR - 0.01', 'MCAR - 0.1', 'MCAR - 0.3', 'MCAR - 0.5', 'MNAR - 0.01', 'MNAR - 0.1', 'MNAR - 0.3', 'MNAR - 0.5']


for i in data_constellations:
    data_constel = heatmap_data_difference.loc[df_heat['Data_Constellation'] == i]

    ### uncomment whatever you want to investigate

    ## sort by amount datapoints (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfInstances'])

    ## sort by amount of features (ascending)
    data_constel = data_constel.sort_values(by=['NumberOfFeatures'])

    ## sort by amount of datapoints and features (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfInstances', 'NumberOfFeatures'])

    ## sort by amount of categorical features and datapoints (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfCategoricalFeatures', 'NumberOfInstances'])

    ## sort by amount of numerical features and datapoints (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfNumericFeatures', 'NumberOfInstances'])
    
    Dataset_number = data_constel["Task"]
    Imputation_Method = data_constel["Imputation_Method"]
    Improvement = data_constel["Performance Difference to Average Best"]
    

    trace = go.Heatmap(
                   z=Improvement,
                   x=Dataset_number,
                   y=Imputation_Method,
                   type = 'heatmap',
                    autocolorscale= False,
                    colorscale = 'RdBu_r',
                    zmid=0,
                    #hoverinfo='text',
                    #text=hovertext
                    )
    data = [trace]
    fig = go.Figure(data=data)
    fig.update_layout(
        title=i,
        xaxis_nticks=36)
    fig.show()
# Out:
# <div>                            <div id="0c1a3573-c0e9-4e16-8937-ab5f7d1b08a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c1a3573-c0e9-4e16-8937-ab5f7d1b08a4")) {                    Plotly.newPlot(                        "0c1a3573-c0e9-4e16-8937-ab5f7d1b08a4",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["1481","184","1481","184","184","184","1481","1481","1481","1481","41027","41027","41027","41027","41027","41027","184","184","183","183","183","183","183","183","40685","40685","40685","40685","40685","40685","30","30","30","30","30","30","40498","40498","40498","40498","40498","40498","32","32","32","32","32","32","41671","41671","41671","41671","41671","40677","40677","40677","40677","40677","40677"],"y":["Discriminative DL","Mean/Mode","GAIN","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","Random Forest","Mean/Mode","GAIN","VAE","KNN","Random Forest","Discriminative DL","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Random Forest","KNN","Mean/Mode","GAIN","Discriminative DL","VAE","VAE","Random Forest","KNN","Mean/Mode","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest"],"z":[0.0010331858387735982,0.0011723571999213145,0.0012287395947483959,0.010172866694780403,-0.0011589090670546809,5.584783911660729e-05,0.0006460233012164918,0.0,0.0015080533764040005,0.0011445672592539091,-0.0003387258977999297,0.0,-0.007032867718828439,-0.006652659947999129,-0.0007832840073520031,-0.00015832978331603575,0.0,0.0035721393483350017,0.001621695779584903,5.061329996661201e-05,0.0017546909367313068,0.0,-3.697415731099274e-05,0.009517919387027812,0.0,-0.009610993315217975,-0.014071865086113966,-0.013854547783178461,-0.012535683906539696,-0.012535683906539696,-0.027614747402239237,0.0,0.035697809283782855,0.03585257013261234,-0.021091808213275276,-0.02940243961573108,0.0,0.01829695643454099,0.017676706813333193,0.032931982162376694,0.01676686799062968,0.016266187535872778,-0.000560845627741946,0.0,-0.0014762516461795938,-0.002058172833317218,-0.00027557140509393285,-0.0014691638610787594,-0.0005486810421910793,7.639886371701987e-05,0.0,-0.0004975023719303862,7.639886371701987e-05,1.8020418994679765e-05,0.0010099253364119765,-0.0008142748637884889,0.0009364864064769218,0.0,0.00048680211145990526],"zmid":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outli ...
# <div>                            <div id="3193da8d-c58c-4a23-909a-60806e28cf8a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3193da8d-c58c-4a23-909a-60806e28cf8a")) {                    Plotly.newPlot(                        "3193da8d-c58c-4a23-909a-60806e28cf8a",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["1481","184","1481","184","184","184","1481","1481","1481","1481","41027","41027","41027","41027","41027","41027","184","184","183","183","183","183","183","183","40685","40685","40685","40685","40685","40685","30","30","30","30","30","30","40498","40498","40498","40498","40498","40498","32","32","32","32","32","32","41671","41671","41671","41671","41671","41671","40677","40677","40677","40677","40677","40677"],"y":["Discriminative DL","Mean/Mode","GAIN","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","Random Forest","Mean/Mode","GAIN","VAE","KNN","Random Forest","Discriminative DL","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","GAIN","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest"],"z":[-0.0035280780469000017,0.0013091395988999999,-0.0005870575104161835,0.0003655450738651034,-0.012262221883197033,-0.0013955730734285243,-0.0019460519005504995,0.0,-0.005629082897933679,-0.007281373915685202,0.00032118850115636643,0.0,0.00028523913796246747,0.029653702384187908,-0.00019019733491865143,0.0005540040424597548,0.0,0.005356072248041299,0.0016901723080019054,0.0016329038937867996,0.006701099638072097,0.0,0.00029510915865629817,0.00010704007323879272,0.0,0.0016756617659337003,-0.0032316702487550364,0.001040373332044764,-0.001953758322449206,0.00015377357475560016,-0.0013094774689550448,0.0,0.05723950602229988,0.06321314523431165,0.06989231673030882,0.019117905423968073,0.0,0.0015248791149461982,-8.619739709347929e-05,0.056708440441328306,-0.0012693392696905004,-0.018947959243355295,-0.001958679533794805,0.0,-0.0014383003429347951,-0.0025373904365667554,-0.0023906141698192274,-0.0023240657411182086,-0.004365809831064105,-0.004808721236379099,0.0,0.014249513633256411,-0.005547191369088905,-0.006909648306008209,0.0049806436795790665,-0.002825607479031822,-0.0001784676452283307,-0.0008093647928231196,0.0,0.009052268815892717],"zmid":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"hea ...
# <div>                            <div id="f06a27fd-f4fb-4bdd-8a07-a642a26647a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f06a27fd-f4fb-4bdd-8a07-a642a26647a7")) {                    Plotly.newPlot(                        "f06a27fd-f4fb-4bdd-8a07-a642a26647a7",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["1481","1481","1481","1481","184","184","184","184","184","184","1481","1481","41027","41027","41027","41027","41027","41027","183","183","183","183","183","183","40685","40685","40685","40685","40685","30","30","30","30","30","30","40498","40498","40498","40498","40498","40498","32","32","32","32","32","32","41671","41671","41671","41671","41671","41671","40677","40677","40677","40677","40677","40677"],"y":["Discriminative DL","Mean/Mode","KNN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","VAE","GAIN","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","Mean/Mode","Discriminative DL","GAIN","VAE","KNN","Random Forest","Mean/Mode","KNN","VAE","GAIN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest"],"z":[-0.008697254683238814,0.008254330215629685,0.0,-0.005234421833505892,0.009801647689246018,0.0016475848573282992,-0.006536840717516701,0.0012564319828962112,0.0,0.018353905678240412,-0.002714596792893098,0.040240082801868,0.0022018092045135162,-0.01395248823860129,-0.011593694377408315,-0.012808122073862394,0.0,0.0026182655136463007,0.0016473548364220048,0.013658689048396302,0.006447370221351209,0.013137659110525404,0.028948839038402105,0.0,-0.001279136229419775,0.014314158010180322,0.0,0.005332102695748797,-0.012410024807419096,0.06907717009177583,0.0,0.10112163732353985,0.10779378455513033,0.03754501815237332,0.08890371355732007,0.07509189028477689,0.0,0.0499822063326531,0.0495594005877979,0.017434688384893315,0.0135971201854716,-0.004833397328707023,0.0,-0.010744826745723968,-0.01691227776240356,-0.00470245985026152,-0.0036577577660700245,-0.02131274083211651,0.0,-0.022491703777891225,-0.020483525545884507,-0.027803126834712616,-0.018613105484950626,0.0069001014300130725,0.007281784780505229,-0.001049721585747232,0.001951192274796676,0.0,-0.004019483950627456],"zmid":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[ ...
# <div>                            <div id="0ed62d9b-a24d-46d9-b402-ef8b1812013c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ed62d9b-a24d-46d9-b402-ef8b1812013c")) {                    Plotly.newPlot(                        "0ed62d9b-a24d-46d9-b402-ef8b1812013c",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["1481","184","1481","184","184","184","1481","1481","1481","1481","41027","41027","41027","41027","41027","41027","184","184","183","183","183","183","183","183","40685","40685","40685","40685","40685","40685","30","30","30","30","30","30","40498","40498","40498","40498","40498","40498","32","32","32","32","32","32","41671","41671","41671","41671","41671","41671","40677","40677","40677","40677","40677","40677"],"y":["Discriminative DL","Mean/Mode","GAIN","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","Random Forest","Mean/Mode","GAIN","VAE","KNN","Random Forest","Discriminative DL","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","GAIN","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest"],"z":[-0.026544481861528912,0.013306909826278607,0.0009765771176943883,-0.002359317392600202,0.010375496857606609,0.019267638380578184,0.009006310225864012,0.0,0.007343158748844586,0.034353559919269305,-0.0007301261961809025,0.0,0.0004293991626632132,-0.002599331491793533,-0.0044838925202270175,-0.0019313232769579969,0.0,-0.005645240488048292,0.010313686229510996,-0.0038838698730653126,0.012177991125514487,0.0,-0.012272597855720213,-0.0006684496642487131,0.0,0.0004245683237434905,0.0039685166489230594,0.009110631620878162,0.0006325341023463715,-0.0005745781671308015,0.04569916514151218,0.0,-0.08950846456078432,-0.012849512465257673,0.0055435665114390575,-0.008845731808865054,0.0,0.0014838910011596984,-0.015087607194033903,-0.02214142282909179,-0.016056571341462794,-0.015141352144091097,-0.0013386590526841546,0.0,-0.003190955704359011,-0.01172931294112678,-0.00805162095148182,-0.0066820723200703425,0.008368643747875187,0.0034418928726628883,0.0,0.0013084283092602012,0.005847579129215907,-0.004349435752188102,0.007630492412556755,-0.014040128788036066,-0.007668141673441209,0.0005458939679335861,0.0,-9.768325265746558e-05],"zmid":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":" ...
# <div>                            <div id="bca3267a-66c2-44ab-b92b-f71f2bff6442" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bca3267a-66c2-44ab-b92b-f71f2bff6442")) {                    Plotly.newPlot(                        "bca3267a-66c2-44ab-b92b-f71f2bff6442",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["1481","184","1481","184","184","184","1481","1481","1481","1481","41027","41027","41027","41027","41027","41027","184","184","183","183","183","183","183","183","40685","40685","40685","40685","40685","40685","30","30","30","30","30","30","40498","40498","40498","40498","40498","40498","32","32","32","32","32","32","41671","41671","41671","41671","41671","40677","40677","40677","40677","40677","40677"],"y":["Discriminative DL","Mean/Mode","GAIN","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","Random Forest","Mean/Mode","GAIN","VAE","KNN","Random Forest","Discriminative DL","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Random Forest","KNN","Mean/Mode","GAIN","Discriminative DL","VAE","VAE","Random Forest","KNN","Mean/Mode","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest"],"z":[-0.00013339538552151198,-0.017113664340054124,-0.00022604227873501692,-0.005885289580404407,-0.012274864892237003,-0.01230692867695421,-0.00039352061938180416,0.0,0.0009962363613125746,0.0022124259016069736,0.0014492561256254088,0.0,-5.4043105238710254e-05,0.002145426340000367,0.0022586278001930915,-7.615091142371133e-05,0.0,-0.011339589654347615,0.012345935210631695,-5.936178753519761e-05,-0.0025662106073053026,0.0,0.0003688960526102014,-3.665768291830074e-05,0.0,-0.002916770360481602,0.00429731223988139,-0.0003902900665193054,-0.0029326106428930743,-0.002916770360481602,0.024275894236158613,0.0,0.039774379203374566,0.022208751333098298,0.011683687867051429,-0.03787823802983359,0.0,-0.0667790287820958,-0.06597358615695631,0.025451877205768192,-0.027780897576122815,-0.017377587667521094,-0.0006513881660668019,0.0,-0.0012462423739307837,0.0007956995158852065,-0.00028773454285746514,-0.0005922878712152357,-0.0005874595740162913,0.00015277611321881657,0.0,-0.00039418803983418127,0.00015277611321881657,-0.001329656184494099,-0.0002744655526590867,0.0028206176675164008,-0.003938458985008442,0.0,0.0008106338523045098],"zmid":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorba ...
# <div>                            <div id="1f3c4672-3cb2-426f-b08a-b50f4759827d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1f3c4672-3cb2-426f-b08a-b50f4759827d")) {                    Plotly.newPlot(                        "1f3c4672-3cb2-426f-b08a-b50f4759827d",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["1481","184","1481","184","184","184","1481","1481","1481","1481","41027","41027","41027","41027","41027","41027","184","184","183","183","183","183","183","183","40685","40685","40685","40685","40685","40685","30","30","30","30","30","30","40498","40498","40498","40498","40498","40498","32","32","32","32","32","32","41671","41671","41671","41671","41671","40677","40677","40677","40677","40677","40677"],"y":["Discriminative DL","Mean/Mode","GAIN","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","Random Forest","Mean/Mode","GAIN","VAE","KNN","Random Forest","Discriminative DL","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Random Forest","KNN","Mean/Mode","GAIN","Discriminative DL","VAE","VAE","Random Forest","KNN","Mean/Mode","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest"],"z":[-0.0011952833478326985,0.008121745711481554,0.037064063285944,0.018421067052609208,0.005743630530713029,0.004968335122312706,0.0016634780536821936,0.0,0.012521398159599184,0.021024397215762186,-0.010646949275833373,0.0,-0.009807023244287671,-0.012267104544789686,0.0006274557524283964,-0.005631237207581075,0.0,0.014607155865900001,0.003966801792478811,-0.0034761278603953893,-0.01074513925494569,0.0,0.00358512207804651,-0.0032579158702326916,0.0,-0.01577493664466051,-0.0058081872900165865,-0.014103213203596088,-0.01577493664466051,-0.01577493664466051,0.08487813453265858,0.0,0.073294029844171,0.11194150234056166,0.0920115487493921,-0.019946676112327588,0.0,-0.0376003701803197,-0.036410755246849114,-0.0420627602093924,-0.032408479931848116,0.026685649643274106,-0.0010307901914567985,0.0,-0.004558430926899226,0.0004290316444324205,-0.0020379908815073566,-0.0020785610970815993,-0.007868401049947488,0.001458445218970511,0.0,-0.009950988737795485,0.0012541271275378907,0.0008226276920464404,-0.002558273579228776,0.004006466542489817,-0.0006694900133050741,0.0,0.00016826299970706948],"zmid":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colo ...
# <div>                            <div id="4502bfd1-15e7-4912-88c3-de246693ab0d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4502bfd1-15e7-4912-88c3-de246693ab0d")) {                    Plotly.newPlot(                        "4502bfd1-15e7-4912-88c3-de246693ab0d",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["1481","184","1481","184","184","184","1481","1481","1481","1481","41027","41027","41027","41027","41027","41027","184","184","183","183","183","183","183","183","40685","40685","40685","40685","40685","40685","30","30","30","30","30","30","40498","40498","40498","40498","40498","40498","32","32","32","32","32","32","41671","41671","41671","41671","41671","41671","40677","40677","40677","40677","40677","40677"],"y":["Discriminative DL","Mean/Mode","GAIN","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","Random Forest","Mean/Mode","GAIN","VAE","KNN","Random Forest","Discriminative DL","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","GAIN","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest"],"z":[0.01897539338349649,0.029317593072729797,0.007700127767006598,0.015990581775170792,0.022027980262386476,0.02568456494971061,0.0138499211667156,0.0,0.005553658367520586,0.008519614255554503,-0.00011840388516748401,0.0,0.015684711392672523,0.00017814331482041146,0.0052155447702906255,-0.0022807458404228154,0.0,0.030691561876890372,0.0031684486158913977,0.0034488638689894047,0.0019263248772347918,0.0,0.0017350632632777974,-0.0014616229710747997,0.0,0.008913320281934478,0.0017007504522515982,0.0026586951930137603,-0.007619317717228347,-0.013063819912889518,0.018225409691301375,0.0,-0.061014374546884076,0.02352495343736749,0.08163732644027177,0.021524336326091298,0.0,-0.0286060351703869,-0.025859309953749604,0.025251828942821908,-0.014973798628878404,-0.053568108720920604,-0.0005799962120623947,0.0,-0.002867649837048014,-0.01082241996463773,-0.005597809963702405,-0.005490138760554375,-0.001331579877542316,0.005961878832417583,0.0,0.00401427481435121,0.006261682364518989,0.00590359621957029,-0.008611464228494903,-0.008877161718962134,-0.013338287893045364,-0.005270016812600753,0.0,-0.014573935030462781],"zmid":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorba ...
# <div>                            <div id="932b2e71-8482-4c32-a896-08fc0eab97c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("932b2e71-8482-4c32-a896-08fc0eab97c5")) {                    Plotly.newPlot(                        "932b2e71-8482-4c32-a896-08fc0eab97c5",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["1481","184","1481","184","184","184","1481","1481","1481","1481","41027","41027","41027","41027","41027","41027","184","184","183","183","183","183","183","183","40685","40685","40685","40685","40685","40685","30","30","30","30","30","30","40498","40498","40498","40498","40498","40498","32","32","32","32","32","32","41671","41671","41671","41671","41671","41671","40677","40677","40677","40677","40677","40677"],"y":["Discriminative DL","Mean/Mode","GAIN","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","Random Forest","Mean/Mode","GAIN","VAE","KNN","Random Forest","Discriminative DL","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","GAIN","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest"],"z":[-0.026544481861528912,0.013306909826278607,0.0009765771176943883,-0.002359317392600202,0.010375496857606609,0.019267638380578184,0.009006310225864012,0.0,0.007343158748844586,0.034353559919269305,-0.0007301261961809025,0.0,0.0004293991626632132,-0.002599331491793533,-0.0044838925202270175,-0.0019313232769579969,0.0,-0.005645240488048292,0.010313686229510996,-0.0038838698730653126,0.012177991125514487,0.0,-0.012272597855720213,-0.0006684496642487131,0.0,0.0004245683237434905,0.0039685166489230594,0.009110631620878162,0.0006325341023463715,-0.0005745781671308015,0.04569916514151218,0.0,-0.08950846456078432,-0.012849512465257673,0.0055435665114390575,-0.008845731808865054,0.0,0.0014838910011596984,-0.015087607194033903,-0.02214142282909179,-0.016056571341462794,-0.015141352144091097,-0.0013386590526841546,0.0,-0.003190955704359011,-0.01172931294112678,-0.00805162095148182,-0.0066820723200703425,0.008368643747875187,0.0034418928726628883,0.0,0.0013084283092602012,0.005847579129215907,-0.004349435752188102,0.007630492412556755,-0.014040128788036066,-0.007668141673441209,0.0005458939679335861,0.0,-9.768325265746558e-05],"zmid":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":" ...
# <div>                            <div id="796e56c7-343f-4820-b693-5799b74acd6f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("796e56c7-343f-4820-b693-5799b74acd6f")) {                    Plotly.newPlot(                        "796e56c7-343f-4820-b693-5799b74acd6f",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["1481","1481","184","184","184","184","184","184","1481","1481","1481","41027","41027","41027","41027","41027","1481","183","183","183","183","183","183","40685","40685","40685","40685","30","30","30","30","30","30","40498","40498","40498","40498","40498","40498","32","32","32","32","32","32","41671","41671","41671","41671","41671","40677","40677","40677","40677","40677","40677"],"y":["VAE","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","KNN","GAIN","Mean/Mode","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","Discriminative DL","Random Forest","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","Random Forest","KNN","Mean/Mode","VAE","Random Forest","GAIN","Discriminative DL","KNN","Mean/Mode","VAE","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","Discriminative DL","GAIN","VAE","Random Forest","Mean/Mode","KNN","Discriminative DL","VAE","GAIN","VAE","Mean/Mode","KNN","Random Forest","Discriminative DL"],"z":[-0.00817415325789908,-0.0012329012683773843,0.0018975229946889272,0.003003544506274325,0.007452495272732007,0.002193437376241336,0.0,0.0020411152508945096,0.0,0.020864183713510703,0.020327377677341107,0.00014847615652707757,0.0,-1.9506486523324096e-05,-9.615212277941376e-05,-2.898837955861433e-05,-0.007362226568420588,-9.680111683270376e-05,-0.007122399271512106,-0.0006772045499835039,-0.0004112124019909069,-0.0005733951577517049,0.0,0.003169369576534631,0.0,0.00027835040904550246,0.010606229020738211,0.007722558728117113,0.002503607828731269,0.02233240273326742,0.0,0.002503607828731269,-0.021837353494745804,-0.0003707221575807995,0.0,0.005675852696571698,0.0057305413065947,0.0385125955857098,-0.001047494408728894,0.0016500400792119896,0.0,0.002000332488692802,-0.0026011659011454524,0.0013884215932328248,0.0016724606522009466,0.0,-0.00017232026886190854,0.0,0.0,-0.0003002385857222012,-0.002362395866076561,-0.0008844625855154442,-0.001674446465509405,0.0,-0.0004924717088848896,0.0004987701354458585],"zmid":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.444444444444444 ...
# <div>                            <div id="3df105ad-c474-49e5-84a9-522e2b38127b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3df105ad-c474-49e5-84a9-522e2b38127b")) {                    Plotly.newPlot(                        "3df105ad-c474-49e5-84a9-522e2b38127b",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["1481","184","1481","184","184","184","1481","1481","1481","1481","41027","41027","41027","41027","41027","41027","184","184","183","183","183","183","183","183","40685","40685","40685","40685","40685","40685","30","30","30","30","30","30","40498","40498","40498","40498","40498","40498","32","32","32","32","32","32","41671","41671","41671","41671","41671","41671","40677","40677","40677","40677","40677","40677"],"y":["Discriminative DL","Mean/Mode","GAIN","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","Random Forest","Mean/Mode","GAIN","VAE","KNN","Random Forest","Discriminative DL","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","GAIN","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest"],"z":[-0.0224213951210889,0.004120482158014249,-0.017732838113418997,0.005873582776218189,0.010459919466544676,0.0012846358844756933,-0.035235070921971284,0.0,-0.014738544349743782,-0.009294710394634781,-0.003387425577841885,0.0,-0.0018661205085833132,0.02228908134966956,-0.004055366025480733,0.00021878421317089725,0.0,-0.011094266940850528,0.0038825900477464093,0.005281289197726607,0.017119792837634304,0.0,6.99414829914008e-05,-0.0004227667542563013,0.0,-0.0027559901870127246,-0.0001398219674010881,-0.0034962483373283115,0.0008495703302621727,-0.0015394398735644188,-0.004422006925800526,0.0,-0.0752606845391468,-0.07629473722118596,-0.04578413580106533,-0.07491961458130314,0.0,-0.05774974150942419,-0.0362412695689287,-0.0337640686107509,0.0016482298473824986,0.011870258839338094,-0.0016776463265889552,0.0,-0.004118695220273749,-0.005002805266424937,3.854401264546947e-05,0.0006445728059462086,-0.002915033140884704,0.0006350420867420048,0.0,-0.0059502281709261085,-0.005080228827364197,0.0020092327747019967,0.005308743224937795,-0.006087139895003979,0.001614730063675518,-0.013151944425967343,0.0,0.013580056286213171],"zmid":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatma ...
# <div>                            <div id="63701e97-8953-45e3-b3a2-e2b059012603" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("63701e97-8953-45e3-b3a2-e2b059012603")) {                    Plotly.newPlot(                        "63701e97-8953-45e3-b3a2-e2b059012603",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["1481","184","1481","184","184","184","1481","1481","1481","1481","41027","41027","41027","41027","41027","41027","184","184","183","183","183","183","183","183","40685","40685","40685","40685","40685","40685","30","30","30","30","30","30","40498","40498","40498","40498","40498","40498","32","32","32","32","32","32","41671","41671","41671","41671","41671","41671","40677","40677","40677","40677","40677","40677"],"y":["Discriminative DL","Mean/Mode","GAIN","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","Random Forest","Mean/Mode","GAIN","VAE","KNN","Random Forest","Discriminative DL","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","GAIN","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest"],"z":[-0.03295877253392249,0.02872234563639192,-0.019411153158508304,-0.02361415150166618,0.013313552040202514,0.01736671370414339,-0.03259050259927018,0.0,-0.015317376329661597,-0.031811702746519094,-0.0075625348651934265,0.0,-0.010268780753853735,0.005455165322385991,-0.009171963424526919,-0.00848657070827763,0.0,0.015804224538098488,-0.0005406931519321007,0.025982892486911296,0.014991754879401298,0.0,-0.00020238767431099425,0.005001582263443702,0.0,-0.001652051298864865,0.0025360542590792123,0.012098539334534586,0.013036284614818205,-0.0009787962846172782,0.036196199052139555,0.0,0.03636396871960068,0.003403049215352505,0.03980352892026562,0.007722558728117113,0.0,-0.019023517269012385,-0.03784304450754458,-0.02716774345796369,-0.06401276575546508,-0.017095362186102192,-0.004004741629786479,0.0,-0.029141043232726704,-0.08948498541430383,-0.006164724285170453,-0.0038901159018368547,0.0006302895616757953,0.0006787676129262066,0.0,0.0050027000943067,-0.005036425909868192,0.0012087554669091005,-0.03684919525357899,-0.017119546440256372,-0.01367827228931473,0.00307898672858975,0.0,-0.008726789024385617],"zmid":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar" ...
# <div>                            <div id="f4384299-31a0-4c5f-80d9-617043e34105" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f4384299-31a0-4c5f-80d9-617043e34105")) {                    Plotly.newPlot(                        "f4384299-31a0-4c5f-80d9-617043e34105",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["1481","184","1481","184","184","184","1481","1481","1481","1481","41027","41027","41027","41027","41027","41027","184","184","183","183","183","183","183","183","40685","40685","40685","40685","40685","40685","30","30","30","30","30","30","40498","40498","40498","40498","40498","40498","32","32","32","32","32","32","41671","41671","41671","41671","41671","41671","40677","40677","40677","40677","40677","40677"],"y":["Discriminative DL","Mean/Mode","GAIN","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","Random Forest","Mean/Mode","GAIN","VAE","KNN","Random Forest","Discriminative DL","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","GAIN","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest"],"z":[8.961667388568406e-05,0.045956818732668187,-0.018424462020850907,0.024431246468830076,0.03666300960560828,0.028346784943251796,-0.00730979770890039,0.0,-0.0080631102850241,-0.004177207553440115,-0.006375076302480187,0.0,-0.01919974702177263,-0.024274843961288595,-0.029943923420022278,-0.020611994171897186,0.0,0.021822156182218777,0.014827976891634703,-0.01370294452633869,-0.005112594416292998,0.0,-0.0177103091877929,-0.010361963230590701,0.0,-0.0014029919363878762,0.010755315564272505,0.0011979551801242216,-0.0016808317742911805,-0.0003760072755079613,0.00015519180736411897,0.0,0.01836201904007939,-0.039455523629880584,-0.03795121701428794,-0.03735531712059503,0.0,0.02344304081847809,0.011603565327661908,-0.015002152335063912,0.010350774299287685,0.0015450197865365944,-0.0026700625731687078,0.0,-0.02629940776763018,-0.012440972519483173,-0.003700791536406345,-0.0182600697799703,-0.021960598852400093,-0.024775514352114086,0.0,-0.024615330971288707,-0.022974061000778895,-0.024663183508549985,0.02518255738428965,0.013718843119885027,0.015592809352605319,-0.024626928057286723,0.0,0.036456564460411234],"zmid":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorba ...

# %% [markdown]
# ## Plotly Heatmaps Tests

# %%
#heatmap_mar001.head()

# %%
#testmar001 = xr.tutorial.open_dataset('air_temperature').air.sel(lon=250.0)

'''
#plotly express test

fig = px.imshow(heatmap_mar001, text_auto = True, 
                labels=dict(x="Task", y="Imputation_Method", color="Improvement"),
                color_continuous_scale='RdBu_r', color_continuous_midpoint=0)
'''
# Out:
# '\n#plotly express test\n\nfig = px.imshow(heatmap_mar001, text_auto = True, \n                labels=dict(x="Task", y="Imputation_Method", color="Improvement"),\n                color_continuous_scale=\'RdBu_r\', color_continuous_midpoint=0)\n'

# %%
### uncomment whatever you want to investigate

## sort by amount datapoints (ascending)
#mar001 = mar001.sort_values(by=['NumberOfInstances'])

## sort by amount of features (ascending)
#mar001 = mar001.sort_values(by=['NumberOfFeatures'])

## sort by amount of datapoints and features (ascending)
#mar001 = mar001.sort_values(by=['NumberOfInstances', 'NumberOfFeatures'])

## sort by amount of categorical features and datapoints (ascending)
#mar001 = mar001.sort_values(by=['NumberOfCategoricalFeatures', 'NumberOfInstances'])

## sort by amount of numerical features and datapoints (ascending)
#mar001 = mar001.sort_values(by=['NumberOfNumericFeatures', 'NumberOfInstances'])



mar001 = mar001.astype({"Task":"string"})

Dataset_number = mar001["Task"]
Imputation_Method = mar001["Imputation_Method"]
Improvement = mar001["Improvement"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2178373/1515415338.py in <module>
#      18
#      19
# ---> 20 mar001 = mar001.astype({"Task":"string"})
#      21
#      22 Dataset_number = mar001["Task"]
#
# NameError: name 'mar001' is not defined

# %%
trace = go.Heatmap(
                   z=Improvement,
                   x=Dataset_number,
                   y=Imputation_Method,
                   type = 'heatmap',
                    autocolorscale= False,
                    colorscale = 'RdBu_r',
                    zmid=0,
                    hoverinfo='text',
                    text=hovertext
                    )




data = [trace]
fig = go.Figure(data=data)
#iplot(fig)


fig.show()

# %% [markdown]
# ToDo´s für Darstellung:
# - Optionen für einfache Anpassung bei der Sortierung/Darstellung:
#     - Anzahl Datenpunkte
#     - Anzahl Features
#     - Anzahl numerische Features
#     - Anzahl kategorische Features
# - Schleife aufsetzen für alle Datenkonstellationen (nicht hart kodieren)
# - Jeweils beste Imputationsmethode je Datensatz nochmals separat in Heatmap
#
#
#
# ToDo´s für restliche Auswertung (Mathematische Part)
# - Beste Imp-Methode je Datensatz ermitteln (-> via Ranking am besten, je Konstellation (Bsp. MAR 0.01)
# - durchschnittliche Platzierung jeder Imp-Methode ermitteln (Ranking -> dann je Konstellation (Bsp. MAR 0.01)
# - Beste Imp je Datensatz mit durchschnittlich bester Imp vergleichen (Liste mit beste Imp & Liste mit Durchschn. Imp -> VGL)
# (jede Konstellation genau einmal in jeder Liste)
#
#
#
# Sonstiges (keine Prio)
# - Optionen für Filterung (bei Beadrf umsetzen -> vorerst keine Priorität!)
#     - Numerisches Feature wurde imputiert
#     - Kategorisches Feature wurde imputiert

# %% [markdown]
# ## Application Scenario 2 - Downstream Performance

# %% [markdown]
# ### Categorical  Columns (Classification)

# %%
'''
draw_cat_box_plot(
    downstream_results,
    "Improvement",
    (-0.15, 0.3),
    FIGURES_PATH,
    "fully_observed_downstream_boxplot.eps",
    hue_order=list(rename_imputer_dict.values()),
    row_order=list(rename_metric_dict.values())
)
'''
# Not used at the moment -> function from other file required, check first field
